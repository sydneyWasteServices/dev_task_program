# %%
import pandas as pd
import numpy as np

# %%
PATH_ROSTER = "D:\\Run Analysis\\blob_storage\\roster\\35th_2021.xlsx"
PATH_SAL = "D:\\Run Analysis\\blob_storage\\driver_salary\\processed\\35th_2021.xlsx"
sal_df = pd.read_excel(PATH_SAL)
# Employee_ID	Hours	 Gross 	Super
roster_df = pd.read_excel(PATH_ROSTER)

sal_df.Employee_ID = sal_df.Employee_ID.str.lower()
sal_df['total'] = sal_df.Gross + sal_df.Super
count_pri_dr = roster_df.groupby(['Primary_employeeID'])['Date'].count().rename("pri_dr")

count_sec_dr = roster_df.groupby(['Secondary_employeeID'])['Date'].count().rename("sec_dr")
count_dr_shifts = pd.concat([count_pri_dr, count_sec_dr], axis=1).fillna(0)
count_dr_shifts['Total'] = count_dr_shifts.pri_dr + count_dr_shifts.sec_dr

count_dr_shifts = count_dr_shifts['Total'].reset_index().rename(columns={"index" : "Employee_ID", "Total" : "total_shifts"})   
sal_shifts_df = sal_df.merge(count_dr_shifts, how="left", on="Employee_ID")

sal_shifts_df['per_shift_pay'] = sal_shifts_df.total / sal_shifts_df.total_shifts
sal_shifts_df['per_shift_pay'] = sal_shifts_df.total / sal_shifts_df.total_shifts

sal_per_shift = sal_shifts_df[["Employee_ID", "per_shift_pay"]]

sal_per_shift
# Out:
#    Employee_ID  per_shift_pay
# 0     swansgia     479.690000
# 1     swbranat     228.958333
# 2     swbraric     341.832500
# 3     swburlei     307.227500
# 4     swdinvie     305.250000
# 5     swedwben     328.550000
# 6     swfiejih     421.240000
# 7     swgooowe            NaN
# 8     swhearay     398.447500
# 9       swhewg     599.360000
# 10      swliqi     288.940000
# 11    swlocbra     613.355000
# 12    swmittai     431.345000
# 13     swnevpj     318.415714
# 14    swpetand     220.935714
# 15     swrigda     468.582000
# 16    swrobgar     385.694000
# 17      swrobg            NaN
# 18    swsinvic     283.484286
# 19    swtaujul     559.792500
# 20    swtubjoh     721.860000
# 21    swtupfek     428.896000
# 22    swvisgre     357.102000
# 23    swwarrob     421.305000
# 24    swwhinei     369.597500
# 25        ir12     235.006667
# 26      irdeaz     312.020000
# 27        ir02     602.442500
# 28        ir20     273.765000

# %%
roster_df.assign(pri_sal = lambda df : df.Primary_employeeID )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-dcd142cadea9> in <module>
# ----> 1 roster_df.assign(pri_sal = lambda df : sal_per_shift.Employee_ID.eq(df['Primary_employeeID']).per_shift_pay  )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    4484
#    4485         for k, v in kwargs.items():
# -> 4486             data[k] = com.apply_if_callable(v, data)
#    4487         return data
#    4488
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     356     """
#     357     if callable(maybe_callable):
# --> 358         return maybe_callable(obj, **kwargs)
#     359
#     360     return maybe_callable
#
# <ipython-input-80-dcd142cadea9> in <lambda>(df)
# ----> 1 roster_df.assign(pri_sal = lambda df : sal_per_shift.Employee_ID.eq(df['Primary_employeeID']).per_shift_pay  )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'per_shift_pay'

# %%
roster_df
# Out:
#           Date    Run_type Primary_employeeID Secondary_employeeID  \
# 0   2021-09-01  NIGHT RUNS            subcon1                  NaN
# 1   2021-09-01    DAY RUNS           swpetand             swhearay
# 2   2021-09-01    DAY RUNS           swpetand                  NaN
# 3   2021-09-01    DAY RUNS           swedwben                  NaN
# 4   2021-09-01    DAY RUNS           swlocbra                  NaN
# ..         ...         ...                ...                  ...
# 107 2021-09-07    DAY RUNS             swliqi                  NaN
# 108 2021-09-07    DAY RUNS           swmittai                  NaN
# 109 2021-09-07    DAY RUNS           swsinvic                 ir12
# 110 2021-09-07    DAY RUNS           swsinvic                 ir12
# 111 2021-09-07    DAY RUNS             irdeaz                  NaN
#
#     Primary_driver_Name Secondary_Driver_Name Primary_route Satellite_Route_1  \
# 0           ALAN WALDEN                   NaN           RLC               NaN
# 1                  ANDY                   RAY           RLK               NaN
# 2         ANDY PETERSON                   NaN           BR1               NaN
# 3           BEN EDWARDS                   NaN           SWG               NaN
# 4            BRAD LOCKE                   NaN           HYG               RL5
# ..                  ...                   ...           ...               ...
# 107            RICKY LI                   NaN        NIWPR1               NaN
# 108       TAIT MITCHELL                   NaN           BR3               NaN
# 109              VICTOR                  LUKE           RLD               NaN
# 110              VICTOR                  LUKE           RLJ               NaN
# 111            ZAC DEAN                   NaN           RL7               NaN
#
#     Satellite_Route_2 Primary_truck Alternative_Truck  \
# 0                 NaN      CQ 64 LO               NaN
# 1                 NaN        XO62AB            XN71FD
# 2                 NaN      XN 75 OS               NaN
# 3                 NaN      XN 72 MK               NaN
# 4             RL6/RLP      CF 71 JM               NaN
# ..                ...           ...               ...
# 107               NaN       XPL 658               NaN
# 108               NaN      XN 06 OJ               NaN
# 109               NaN      CL 02 TB               NaN
# 110               NaN      CL O2 TB               NaN
# 111               NaN      XN 44 QZ               NaN
#
#     Subcontracted_From/Special_Client  Note
# 0                                 NaN   NaN
# 1                                 NaN   NaN
# 2                                 NaN   NaN
# 3                                 NaN   NaN
# 4                                 NaN   NaN
# ..                                ...   ...
# 107                             VISY    NaN
# 108                               NaN   NaN
# 109                               NaN   NaN
# 110                               NaN   NaN
# 111                               NaN   NaN
#
# [112 rows x 13 columns]

# %%
count_dr_shifts
# Out:
#           pri_dr  sec_dr  Total
# ir02         3.0     1.0    4.0
# ir12         2.0     4.0    6.0
# irdeaz       5.0     0.0    5.0
# subcon1      3.0     0.0    3.0
# swansgia     5.0     0.0    5.0
# swbranat     5.0     1.0    6.0
# swbraric     4.0     0.0    4.0
# swburlei     4.0     0.0    4.0
# swdinvie     5.0     0.0    5.0
# swedwben     5.0     0.0    5.0
# swfiejih     2.0     1.0    3.0
# swhearay     2.0     2.0    4.0
# swhewg       1.0     0.0    1.0
# swliqi       4.0     0.0    4.0
# swlocbra     4.0     0.0    4.0
# swmittai     4.0     0.0    4.0
# swnevpj      7.0     0.0    7.0
# swpetand     7.0     0.0    7.0
# swrigda      5.0     0.0    5.0
# swrobgar     5.0     0.0    5.0
# swsinvic     7.0     0.0    7.0
# swtaujul     4.0     0.0    4.0
# swtubjoh     1.0     0.0    1.0
# swtupfek     5.0     0.0    5.0
# swvisgre     5.0     0.0    5.0
# swwarrob     4.0     0.0    4.0
# swwhinei     4.0     0.0    4.0
# ir20         0.0     6.0    6.0

# %%
count_dr_shifts = count_dr_shifts['Total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-132a6e149673> in <module>
# ----> 1 count_dr_shifts = count_dr_shifts['Total']
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Total'

# %%
# Out:
#    Employee_ID  Hours    Gross   Super    total
# 0     swansgia  55.10  2278.21  120.24  2398.45
# 1     swbranat  42.05  1270.39  103.36  1373.75
# 2     swbraric  30.65  1252.59  114.74  1367.33
# 3     swburlei  41.42  1134.14   94.77  1228.91
# 4     swdinvie  40.70  1403.06  123.19  1526.25
# 5     swedwben  49.35  1543.96   98.79  1642.75
# 6     swfiejih  32.65  1133.48  130.24  1263.72
# 7     swgooowe   0.00  1504.00    0.00  1504.00
# 8     swhearay  54.00  1502.09   91.70  1593.79
# 9       swhewg  17.85   520.32   79.04   599.36
# 10      swliqi  33.00  1061.65   94.11  1155.76
# 11    swlocbra  52.75  2337.26  116.16  2453.42
# 12    swmittai  43.00  1597.65  127.73  1725.38
# 13     swnevpj  52.50  2097.70  131.21  2228.91
# 14    swpetand  32.05  1434.14  112.41  1546.55
# 15     swrigda  48.35  2217.46  125.45  2342.91
# 16    swrobgar  53.85  1823.50  104.97  1928.47
# 17      swrobg   4.50   236.28    0.00   236.28
# 18    swsinvic  54.60  1879.42  104.97  1984.39
# 19    swtaujul  47.75  2150.68   88.49  2239.17
# 20    swtubjoh  17.70   674.76   47.10   721.86
# 21    swtupfek  56.50  2029.41  115.07  2144.48
# 22    swvisgre  41.50  1643.36  142.15  1785.51
# 23    swwarrob  48.50  1580.25  104.97  1685.22
# 24    swwhinei  44.40  1375.84  102.55  1478.39
# 25        ir12  48.00  1309.28  100.76  1410.04
# 26      irdeaz  45.50  1450.67  109.43  1560.10
# 27        ir02  38.00  2190.70  219.07  2409.77
# 28        ir20  44.25  1542.84   99.75  1642.59

# %%
# count_dr_shifts = count_dr_shifts.rename('total_shifts').reset_index().rename(columns={"index" : "Employee_ID"})





# .reset_index().rename(columns={"index" : "Employee_ID"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-747461bb4828> in <module>
#       2
#       3
# ----> 4 count_dr_shifts.rename(index='Employee_ID')
#       5
#       6
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5037         4  3  6
#    5038         """
# -> 5039         return super().rename(
#    5040             mapper=mapper,
#    5041             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1145             # GH 13473
#    1146             if not callable(replacements):
# -> 1147                 indexer = ax.get_indexer_for(replacements)
#    1148                 if errors == "raise" and len(indexer[indexer == -1]):
#    1149                     missing_labels = [
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    5273         """
#    5274         if self._index_as_unique:
# -> 5275             return self.get_indexer(target, **kwargs)
#    5276         indexer, _ = self.get_indexer_non_unique(target)
#    5277         return indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3435         # returned ndarray is np.intp
#    3436         method = missing.clean_reindex_fill_method(method)
# -> 3437         target = self._maybe_cast_listlike_indexer(target)
#    3438
#    3439         self._check_indexing_method(method, limit, tolerance)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_listlike_indexer(self, target)
#    5706         Analogue to maybe_cast_indexer for get_indexer instead of get_loc.
#    5707         """
# -> 5708         return ensure_index(target)
#    5709
#    5710     @final
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    6334     else:
#    6335
# -> 6336         return Index(index_like, copy=copy)
#    6337
#    6338
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     472
#     473         elif is_scalar(data):
# --> 474             raise cls._scalar_data_error(data)
#     475         elif hasattr(data, "__array__"):
#     476             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 'Employee_ID' was passed

# %%
# Out:
#    Employee_ID  Hours    Gross   Super    total  Total_shifts
# 0     swansgia  55.10  2278.21  120.24  2398.45           5.0
# 1     swbranat  42.05  1270.39  103.36  1373.75           6.0
# 2     swbraric  30.65  1252.59  114.74  1367.33           4.0
# 3     swburlei  41.42  1134.14   94.77  1228.91           4.0
# 4     swdinvie  40.70  1403.06  123.19  1526.25           5.0
# 5     swedwben  49.35  1543.96   98.79  1642.75           5.0
# 6     swfiejih  32.65  1133.48  130.24  1263.72           3.0
# 7     swgooowe   0.00  1504.00    0.00  1504.00           NaN
# 8     swhearay  54.00  1502.09   91.70  1593.79           4.0
# 9       swhewg  17.85   520.32   79.04   599.36           1.0
# 10      swliqi  33.00  1061.65   94.11  1155.76           4.0
# 11    swlocbra  52.75  2337.26  116.16  2453.42           4.0
# 12    swmittai  43.00  1597.65  127.73  1725.38           4.0
# 13     swnevpj  52.50  2097.70  131.21  2228.91           7.0
# 14    swpetand  32.05  1434.14  112.41  1546.55           7.0
# 15     swrigda  48.35  2217.46  125.45  2342.91           5.0
# 16    swrobgar  53.85  1823.50  104.97  1928.47           5.0
# 17      swrobg   4.50   236.28    0.00   236.28           NaN
# 18    swsinvic  54.60  1879.42  104.97  1984.39           7.0
# 19    swtaujul  47.75  2150.68   88.49  2239.17           4.0
# 20    swtubjoh  17.70   674.76   47.10   721.86           1.0
# 21    swtupfek  56.50  2029.41  115.07  2144.48           5.0
# 22    swvisgre  41.50  1643.36  142.15  1785.51           5.0
# 23    swwarrob  48.50  1580.25  104.97  1685.22           4.0
# 24    swwhinei  44.40  1375.84  102.55  1478.39           4.0
# 25        ir12  48.00  1309.28  100.76  1410.04           6.0
# 26      irdeaz  45.50  1450.67  109.43  1560.10           5.0
# 27        ir02  38.00  2190.70  219.07  2409.77           4.0
# 28        ir20  44.25  1542.84   99.75  1642.59           6.0
