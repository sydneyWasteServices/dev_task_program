# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs

# %%
PATH_LINKT = "D:\\Run Analysis\\blob_storage\\toll_tag_id_source.html"

with open(PATH_LINKT, 'r') as f:
    contents = f.read()
    soup = bs(contents, 'html.parser')
#     print(soup.prettify())
    data = []
    print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
# <head>
# <title>Manage Tags - Linkt</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="app-id=1166823295" name="apple-itunes-app"/>
# <meta content="app-id=com.transurban.linkt" name="google-play-app"/>
# <script data-dtconfig="app=a4a0e9efac740b9f|rcdec=1209600000|featureHash=ICA2SVfhjqrux|vcv=2|rdnt=1|uxrgce=1|srcss=1|srmcrv=10|cuc=yz7ckjw8|mel=100000|md=mdcc1=a#emailAddress@value|lastModification=1615667150357|dtVersion=10177191024092634|srmcrl=1|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/retailweb/ruxitagentjs_ICA2SVfhjqrux_10177191024092634.js|reportUrl=/retailweb/rb_bf52197vme|rid=RID_1351823036|rpid=-1939190549|domain=linkt.com.au" src="/retailweb/ruxitagentjs_ICA2SVfhjqrux_10177191024092634.js" type="text/javascript"></script><link href="/retailweb/resources/retailer/linkt/css/normalize.css" rel="stylesheet"/>
# <link href="/retailweb/resources/retailer/linkt/img/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/retailweb/resources/retailer/linkt/img/icons/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/retailweb/resources/vendor/fancybox/jquery.fancybox.css" rel="stylesheet">
# <link href="/retailweb/resources/vendor/footable/footable.core.min.css" rel="stylesheet"/>
# <link href="/retailweb/resources/vendor/jquery/jquery-ui.css" rel="stylesheet"/>
# <link href="/retailweb/resources/retailer/linkt/css/main.css" rel="stylesheet"/>
# <link href="/retailweb/resources/retailer/linkt/css/datepicker.css" rel="stylesheet"/>
# <link href="/retailweb/resources/retailer/linkt/css/media-queries.css" rel="stylesheet"/>
# <link href="/retailweb/resources/vendor/headerui/header-footer-linkt.css" rel="stylesheet"/>
# <link href="/retailweb/resources/retailer/linkt/css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/retailweb/resources/common/css/iglide-common.css" rel="stylesheet"/>
# <script src="/retailweb/resources/vendor/jquery/modernizr-2.6.2.min.js"></script>
# <script src="/retailweb/resources/vendor/jquery/jquery-1.10.2.min.js"></script>
# <script src="/retailweb/resources/vendor/jquery/jquery-ui.min.js"></script>
# <script src="/retailweb/resources/vendor/jquery/jquery.preventDoubleSubmit.js"></script>
# <script>window.DDIGITAL = window.DDIGITAL || {};</script>
# <script src="/retailweb/resources/vendor/headerui/_modernizr-custom.js"></script>
# <script src="/retailweb/resources/vendor/headerui/header-footer-min.js"></script>
# <script src="/retailweb/resources/vendor/cloudflare/lottie.min.js"></script>
# <!-- Debug - 'base' -->
# <div class="viewport clearfix">
# <div class="frame clearfix">
# <div class="outer-container">
# <div class="outer-wrap">
# <div class="inner-wrap" id="inner-wrap">
# <div class="header theme--roamexpress disableFromPrint" id="header">
# <div class="top cf">
# <div class="header__wrapper">
# <a class="nav-toggle js-offscreen-toggle" href="#nav"><span class="vh">Open navigation</span></a>
# <div class="logo">
# <a href="javascript:openContentPage('', 'Main','Open navigation');">
# <img alt="Linkt homepage" src="/retailweb/resources/retailer/linkt/img/logos/linkt_logo.svg"/>
# </a>
# </div>
# <div class="header__actions">
# <div class="header__nav fn_header__nav">
# <div class="navbar">
# <ul class="nav nav--main cf">
# <li class="has-children" id="dropdown-nav-0-item-1"><a class="has-no-landing" href="#"> Using toll roads<span class="subtitle"></span>
# </a>
# <div class="fn_dropdown dropdown" style="">
# <div class="dropdown__content cf">
# <ul class="no-children">
# <li><a href="javascript:openContentPage('using-toll-roads/toll-calculator', 'Main','Toll calculator')"><span class="cms-icon-small"></span>
# 																			Toll calculator</a></li>
# <li><a href="javascript:openContentPage('using-toll-roads/how-to-pay-for-travel', 'Main','How to pay for travel')"><span class="cms-icon-small"></span>
# 																			How to pay for travel</a></li>
# <li><a href="javascript:openContentPage('using-toll-roads/traffic-and-alerts', 'Main','Traffic and alerts')"><span class="cms-icon-small"></span>
# 																			Traffic and alerts</a></li>
# <li><a href="javascript:openContentPage('using-toll-roads/about-sydney-toll-roads', 'Main','About Sydney toll roads')"><span class="cms-icon-small"></span>
# 																			About Sydney toll roads</a></li>
# <li><a href="javascript:openContentPage('using-toll-roads/trip-compare', 'Main','Trip Compare')"><span class="cms-icon-small"></span>
# 																			Trip Compare</a></li>
# <li><a href="javascript:openContentPage('using-toll-roads/news', 'Main','News')"><span class="cms-icon-small"></span>
# 																			News</a></li>
# </ul>
# </div>
# </div></li>
# <li class="" id="dropdown-nav-0-item-2"><a class="has-icon" href="javascript:openContentPage('help', 'Main','Help');"> Help<span class="icon icon--help" style="background-image: none;">
# <svg viewbox="0 0 14.2 14.2" xmlns="http://www.w3.org/2000/svg">
# <path class="fill" d="M7.1 0C3.2 0 0 3.2 0 7.1s3.2 7.1 7.1 7.1 7.1-3.2 7.1-7.1S11 0 7.1 0zm.3 11c-.2.1-.4.2-.6.2-.2 0-.4-.1-.5-.2-.2-.2-.2-.4-.2-.6 0-.4.2-.7.6-.8h.1c.2 0 .4.1.6.2.1.2.2.4.2.6 0 .2-.1.4-.2.6zm1.7-5l-.3.6c-.2.3-.5.5-.8.8l-.6.6c-.1.2-.1.4-.1.6v.3h-1v-.5c0-.3.1-.7.2-1 .2-.3.4-.6.7-.8s.6-.5.8-.8c.1-.2.1-.4.1-.6 0-.2-.1-.5-.2-.6-.2-.2-.5-.2-.8-.2-.2 0-.5 0-.7.1-.3.1-.5.2-.8.3l-.2.1-.4-1 .2-.1c.6-.3 1.3-.5 2-.5.6 0 1.1.1 1.5.5s.6.9.6 1.4c-.1.3-.1.5-.2.8z"></path></svg>
# </span>
# </a></li>
# </ul>
# </div>
# </div>
# <div class="header__btns">
# <ul class="horizontal">
# <li><a "="" class="has-icon btn--call" href="javascript:openContentPage('help', 'Main','Help');"> <span class="icon icon--phone" style="background-image: none;">
# <svg id="Layer_1" style="enable-background: new 0 0 14.2 14.2;" version="1.1" viewbox="0 0 14.2 14.2" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <path class="fill" d="M7.1,0C3.2,0,0,3.2,0,7.1s3.2,7.1,7.1,7.1s7.1-3.2,7.1-7.1S11,0,7.1,0z M7.4,11c-0.2,0.1-0.4,0.2-0.6,0.2
# 												c-0.2,0-0.4-0.1-0.5-0.2c-0.2-0.2-0.2-0.4-0.2-0.6c0-0.4,0.2-0.7,0.6-0.8h0.1c0.2,0,0.4,0.1,0.6,0.2c0.1,0.2,0.2,0.4,0.2,0.6
# 												C7.6,10.6,7.5,10.8,7.4,11z M9.1,6C9,6.2,8.9,6.4,8.8,6.6C8.6,6.9,8.3,7.1,8,7.4C7.8,7.6,7.6,7.8,7.4,8C7.3,8.2,7.3,8.4,7.3,8.6v0.3
# 												h-1V8.4c0-0.3,0.1-0.7,0.2-1c0.2-0.3,0.4-0.6,0.7-0.8S7.8,6.1,8,5.8c0.1-0.2,0.1-0.4,0.1-0.6C8.1,5,8,4.7,7.9,4.6
# 												C7.7,4.4,7.4,4.4,7.1,4.4c-0.2,0-0.5,0-0.7,0.1C6.1,4.6,5.9,4.7,5.6,4.8L5.4,4.9L5,3.9l0.2-0.1c0.6-0.3,1.3-0.5,2-0.5
# 												c0.6,0,1.1,0.1,1.5,0.5s0.6,0.9,0.6,1.4C9.2,5.5,9.2,5.7,9.1,6z" id="Did_You_Know"></path>
# </svg>
# </span> <span class="text"> Click to call</span>
# </a></li>
# <li>
# <div class="header__nav header__nav--login">
# <div class="navbar">
# <ul class="nav nav--main cf">
# <li class="has-children"><a class="has-subtitle has-icon primary" href="/retailweb/logout" onclick=" return invokeNavigationBar_AA('authenticatedTopNav', 'Main','logout');">Log out<span class="icon icon--login" data-grunticon-embed="">
# <svg viewbox="0 0 14.4 14.4" xmlns="http://www.w3.org/2000/svg">
# <path class="fillup" d="M7.2 0C3.2 0 0 3.2 0 7.2s3.2 7.2 7.2 7.2 7.2-3.2 7.2-7.2S11.2 0 7.2 0zm0 3.6c.8 0 1.4.7 1.4 1.4 0 .8-.6 1.4-1.4 1.4S5.8 5.8 5.8 5s.6-1.4 1.4-1.4zm2.5 5.9c0 .9-1 1.1-2.5 1.1-1.6 0-2.5-.2-2.5-1.1v-.8c0-.9.8-1.7 1.7-1.7h1.7c.9 0 1.7.7 1.7 1.7l-.1.8z"></path></svg>
# </span> <span class="subtitle">craig</span> </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <!-- //header__btns -->
# </div>
# <!-- //header__actions -->
# </div>
# <!-- //header__wrapper -->
# </div>
# <!-- //top -->
# </div>
# <!-- //header -->
# <div class="offscreen-nav fn_offscreen-nav js-offscreen-nav disableFromPrint" data-offscreen-at="0,m" id="nav" role="navigation" tabindex="-1">
# <a class="nav-close" href="#"><span class="icon icon--close" style="background-image: none;"><svg viewbox="0 0 19 19" xmlns="http://www.w3.org/2000/svg">
# <path class="fill" d="M1.3 19c.3 0 .6-.1.9-.4l7.3-7.3 7.3 7.3c.2.2.6.4.9.4.3 0 .6-.1.9-.4.5-.5.5-1.3 0-1.8l-7.3-7.3 7.3-7.3c.2-.3.4-.6.4-.9s-.1-.7-.4-.9c-.5-.5-1.3-.4-1.7 0L9.5 7.7 2.2.4C1.9.1 1.6 0 1.3 0 .9 0 .6.1.4.4c-.3.2-.4.5-.4.9s.1.6.4.9l7.3 7.3-7.3 7.3c-.3.3-.4.6-.4 1 0 .3.1.6.4.9.2.2.6.3.9.3z"></path></svg></span>
# 						Close</a>
# <div class="nav-account">
# <a class="btn fn_btn--login btn--login" href="/retailweb/account/home/sydney" onclick=" return invokeNavigationBar_AA('authenticatedTopNav', 'Main','My Account');"> <!-- editable icon-->
# <span class="icon icon--login icon--white" style="background-image: none;"><svg viewbox="0 0 14.4 14.4" xmlns="http://www.w3.org/2000/svg">
# <path class="fill" d="M7.2 0C3.2 0 0 3.2 0 7.2s3.2 7.2 7.2 7.2 7.2-3.2 7.2-7.2S11.2 0 7.2 0zm0 3.6c.8 0 1.4.7 1.4 1.4 0 .8-.6 1.4-1.4 1.4S5.8 5.8 5.8 5s.6-1.4 1.4-1.4zm2.5 5.9c0 .9-1 1.1-2.5 1.1-1.6 0-2.5-.2-2.5-1.1v-.8c0-.9.8-1.7 1.7-1.7h1.7c.9 0 1.7.7 1.7 1.7l-.1.8z"></path></svg></span>
# <span class="text">My Account</span> <br/>
# <span class="text" style="padding-top: 10px;">craig</span>
# </a>
# </div>
# <nav>
# <div class="nav-inner">
# <h2 class="visuallyhidden">
# 									Navigation</h2>
# <div class="nav-main">
# <ul>
# <li class=""><a class="nav-lvl1" href="javascript:openContentPage('', 'Main','Home');"> Home</a></li>
# <li class="has-children"><a aria-controls="nav-ec-2" class="nav-lvl1 nav--ec js-ec-link has-subtitle" href="#nav-ec-2">Using toll roads<span class="subtitle">
# </span>
# <div class="ec"></div></a>
# <div aria-expanded="false" class="menu js-ec" id="nav-ec-2" role="region" tabindex="-1">
# <div class="nav-back cf">
# <a aria-controls="nav-ec-2" class="nav-lvl2 js-ec-link" href="#nav-ec-2">Back
# 															<div class="ec"></div>
# </a>
# </div>
# <div class="menu__title">
# <a class="nav-lvl1 has-subtitle has-no-landing" href="#">
# 															Using toll roads</a>
# </div>
# <ul>
# <li class=""><a class="nav-lvl2" href="javascript:openContentPage('using-toll-roads/toll-calculator', 'Main','Toll calculator')">Toll calculator</a></li>
# <li class=""><a class="nav-lvl2" href="javascript:openContentPage('using-toll-roads/how-to-pay-for-travel', 'Main','How to pay for travel')">How to pay for travel</a></li>
# <li class=""><a class="nav-lvl2" href="javascript:openContentPage('using-toll-roads/traffic-and-alerts', 'Main','Traffic and alerts')">Traffic and alerts</a></li>
# <li class=""><a class="nav-lvl2" href="javascript:openContentPage('using-toll-roads/about-sydney-toll-roads', 'Main','About Sydney toll roads')">About Sydney toll roads</a></li>
# <li class=""><a class="nav-lvl2" href="javascript:openContentPage('using-toll-roads/trip-compare', 'Main','Trip Compare')">Trip Compare</a></li>
# <li class=""><a class="nav-lvl2" href="javascript:openContentPage('using-toll-roads/news', 'Main','News')">News</a></li>
# </ul>
# </div></li>
# <li class=""><a class="nav-lvl1" href="javascript:openContentPage('help');"> Help</a></li>
# </ul>
# </div>
# <div class="nav-supplementary nav-supplementary--offscreen fn_nav-supplementary--offscreen">
# <div class="btn-container btn-logout-container">
# <a class="btn-logout" href="/retailweb/logout">Log out</a>
# </div>
# </div>
# </div></nav>
# </div>
# <script>
# function openContentPage(subpath, navigationBarLocation, linkName){
#
# 	if(navigationBarLocation != null && navigationBarLocation != undefined && navigationBarLocation != '' && linkName != null && linkName != undefined && linkName != '')
# 	{
# 		invokeNavigationBar_AA('authenticatedTopNav', navigationBarLocation, linkName);
# 	}
#
# 	redirectToCMSSite(subpath, true, "https://www.linkt.com.au/", "new", "https://www.linkt.com.au/sydney");
#
# }
#
# function checkUserCredentails(){
#
#
#   	$("input#ssname").val("craig");
# 	$("input#ssclass").val("logged-in");
#
#
# }
# </script><input id="userAccountId" name="accountId" type="hidden" value="3431788415"/>
# <input id="accountProductType" name="accountProductType" type="hidden" value="tagaccount"/>
# <input id="gaAccountId" name="gaAccountId" type="hidden" value="UA-9250181-37"/>
# <input id="igAppContextPath" name="igAppContextPath" type="hidden" value="/retailweb"/>
# <div class="ball-pulse hide" id="processingBtn">Processing <div></div><div></div><div></div></div>
# <script src="/retailweb/resources/common/js/iglide-common.js"></script>
# <input id="retailerCode" type="hidden" value="sydney"/>
# <input id="retailerBrand" type="hidden" value="sydney">
# <input id="originalRetailer" type="hidden" value="eway"/>
# <input id="oldRMSId" type="hidden" value=""/>
# <input id="pageIdentifier" type="hidden" value="null">
# <input id="eventCategoryLogin" type="hidden" value="Login">
# <input id="eventCategoryLogout" type="hidden" value="Logout"/>
# <input id="eventCategoryPassword" type="hidden" value="Reset Password"/>
# <input id="eventCategoryFindUserName" type="hidden" value="Retrieve Username"/>
# <input id="eventCategoryMigrateUser" type="hidden" value="migrateUser"/>
# <input id="eventCategoryNavBarLoc" type="hidden" value="Navigation"/>
# <input id="eventCategoryOpenAccount" type="hidden" value="Open Account"/>
# <input id="eventCategoryPassPurchase" type="hidden" value="Buy Pass"/>
# <input id="eventCategoryMakePayment" type="hidden" value="Make Payment"/>
# <input id="eventCategoryPayTransferInvoice" type="hidden" value="LTI"/>
# <input id="eventCategoryNominateInvoice" type="hidden" value="LTI Nomination"/>
# <input id="eventCategoryVehicleMaintenance" type="hidden" value="Vehicle Management"/>
# <input id="eventCategoryEtag" type="hidden" value="Tags"/>
# <input id="eventCategoryUpdateAccount" type="hidden" value="Update Account Details"/>
# <input id="eventCategoryResetPin" type="hidden" value="resetPin"/>
# <input id="eventCategoryAutoPay" type="hidden" value="Auto Payments"/>
# <input id="eventCategoryManualPay" type="hidden" value="Manual Payments"/>
# <input id="eventCategoryFinHist" type="hidden" value="Financial History"/>
# <input id="eventCategoryTripHist" type="hidden" value="Trip History"/>
# <input id="eventCategoryStatement" type="hidden" value="Statements"/>
# <input id="eventCategoryCantFindAddrs" type="hidden" value="Cannot Find Address"/>
# <input id="eventCategoryReportFaultyTag" type="hidden" value="Report Faulty Tag"/>
# <input id="eventCategoryBulkUpload" type="hidden" value="BulkUpload"/>
# <input id="eventCategoryBulkRemove" type="hidden" value="BulkRemove"/>
# <input id="eventSNAT" type="hidden" value="natDebtAlert"/>
# <input id="eventCategorySNAT" type="hidden" value="natDebt"/>
# <input id="eventAlertSNATClose" type="hidden" value="NAT Debt Alert"/>
# <input id="eventNameSNATClose" type="hidden" value="Close"/>
# <input id="eventAlertSNATRemove" type="hidden" value="Remove this alert"/>
# <input id="eventNameSnatRemoveSuccess" type="hidden" value="Remove"/>
# <input id="eventNameSnatRemoveFailure" type="hidden" value="Remove Error"/>
# <input id="eventNameSnatRemoveSuccess" type="hidden" value="Remove"/>
# <input id="eventSNATCancel" type="hidden" value="Cancel"/>
# <input id="eventAlertSnatWhyAmIReceivingThis" type="hidden" value="Why am I receiving this"/>
# <input id="eventNameSnatWhyAmIReceivingThis" type="hidden" value="Why am I receiving this"/>
# <input id="eventAlertSnatFindTollInvoice" type="hidden" value="Find Toll Invoice"/>
# <input id="eventnameSnatFindTollInvoice" type="hidden" value="Find Toll Invoice"/>
# <input id="eventServiceOutage" type="hidden" value="outage"/>
# <input id="eventCategoryServiceOutage" type="hidden" value="Partial System Outage"/>
# <input id="eventCategoryVivaDigitalRedeem" type="hidden" value="Rewards"/>
# <script src="/retailweb/resources/common/js/iglide-analytics.js"> </script>
# <script src="https://assets.adobedtm.com/560839ab6032d2114ca2149d9e654db4f0a0e3a2/satelliteLib-eff6ca5b33567fc2f7ecc08d56bfb65de91b63b8.js"></script>
# </input></input></input></div></div></div></div></div></link></head>
# <body>
# <!--[if lt IE 7]>
#             <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
#        <![endif]-->
# <div class="main page-account my-account">
# <input id="allocateEtagSearchURL" type="hidden" value="/retailweb/tags/manage/getvehicles/sydney"/> <input id="allocateEtagSubmitURL" type="hidden" value="/retailweb/tags/manage/allocate/sydney"/> <input id="etagdeallocationURL" type="hidden" value="/retailweb/etags/manage/etagdeallocation/sydney"/>
# <div class="container clearfix">
# <div class="my-account-aside fr disableFromPrint paddingBottom12">
# <aside>
# <ul class="side-nav">
# <!-- My account button -->
# <li><a class="first" href="/retailweb/account/home/sydney#anchor-to-account">
# 							My Account
# 					</a></li>
# <!-- My details button -->
# <li><a class="" href="/retailweb/changedetails/sydney">
# 							My details
# 					</a></li>
# <!-- Auto payment button -->
# <li>
# <a class="first" href="/retailweb/changepayment/sydney">
# 										Payment details
# 								</a>
# </li>
# <!-- Vehicle button -->
# <li><a class="" href="/retailweb/maintainvehicles/consumer/sydney">
# 								Vehicles
# 						</a></li>
# <!-- Tag's button -->
# <li><a class="" href="/retailweb/tags/manage/sydney">
# 								Tags
# 						</a></li>
# <!-- Financial history button -->
# <li><a class="" href="/retailweb/finance/financialhistory/results/sydney">
# 							Financial history
# 					</a></li>
# <!-- Trip history button -->
# <li><a class="" href="/retailweb/trips/triphistory/results/sydney">
# 							Trip history
# 					</a></li>
# <!-- Export trip history button -->
# <li><a class="" href="/retailweb/trips/triphistory/export/sydney">
# 							Export trips
# 					</a></li>
# <li>
# <!-- Statements button -->
# <a class="" href="/retailweb/statements/sydney">
# 									Statements
# 								</a>
# </li>
# <li><a class="" href="/retailweb/cashback/display/sydney">
# 														Cashback and rebates
# 														 </a></li>
# <!-- Pay toll notice button -->
# <li><a class="" href="/retailweb/lti/multiple/paytoll/sydney">
# 								Pay toll notice
# 						</a></li>
# <!-- Rewards button [Start] -->
# <li><a class="" href="/retailweb/rewards/sydney">
# 								Rewards
# 						</a></li>
# <!-- Rewards button [End] -->
# <!-- Logout button -->
# <li><a class="" href="/retailweb/logout" onclick="invokeLogout_AA('logout');">
# 					Log out
# 			</a></li>
# </ul>
# </aside>
# <a class="link-help" href="javascript:openContentPage('help');"> Help &amp; support
# 			</a>
# <input id="currentPage" name="currentPage" type="hidden" value="Linkt Home / Linkt"/>
# </div>
# <script>
#
# 	function openContentPage(subpath) {
#
# 		redirectToCMSSite(subpath, false, "https://www.linkt.com.au/", "new", "https://www.linkt.com.au/sydney");
#
# 	}
#
# 	function checkUserCredentails() {
#
#
# 	  		$("input#ssname").val("craig izzard");
# 			$("input#ssclass").val("logged-in");
#
#
# 	}
# </script>
# <!-- jsp:include page="sydney/sidemenu.jsp"/-->
# <div class="my-account-main fl">
# <div class="row-account row-account-edit clearfix">
# <h1 class="title-page fl">
# 					Tags</h1>
# </div>
# <div class="row-account">
# <p>
# 						Make sure you travel with your tag, and that it is installed correctly or you may be charged a no tag in vehicle fee. <a href='javascript:openContentPage("help/tags-and-holders");' javascriptescape="true">Need more info?</a></p>
# <!-- box for server side validation as fallback for javascript validation -->
# <div class="error-box clearfix" id="errorSection" style="display: none">
# <label class="error"></label>
# </div>
# <div class="clearfix">
# <p>
# </p>
# <form action="/retailweb/tags/reportaslost/selectetag/sydney" id="reportEtagAsLostForm" method="POST"><div class="container-fluid tagAlign">
# <div class="tagBox showcursor grayBorder">
# <div class="addtagDetailsBtn">
# <div class="paddingTop6 paddingLeft12 leftAlign"><a href="/retailweb/tags/order/sydney#order-etags">
# <div class="inlineBox">
# <svg class="" height="36px" version="1.1" viewbox="0 0 96 96" width="36px">
# <g fill="none" fill-rule="evenodd" id="Icons" stroke="none" stroke-width="1">
# <g fill="#14a248" id="icon-add-card">
# <g id="A/Icon/Add">
# <path d="M48,0 C21.4911618,0 0,21.4911618 0,48 C0,74.5088382 21.4911618,96 48,96 C74.5088382,96 96,74.5088382 96,48 C96,21.4911618 74.5088382,0 48,0 L48,0 Z M75.4289894,51.4289894 L51.4289894,51.4289894 L51.4289894,75.4289894 L44.5710106,75.4289894 L44.5710106,51.4289894 L20.5710106,51.4289894 L20.5710106,44.5710106 L44.5710106,44.5710106 L44.5710106,20.5710106 L51.4289894,20.5710106 L51.4289894,44.5710106 L75.4289894,44.5710106 L75.4289894,51.4289894 Z" id="Page-1"></path>
# </g>
# </g>
# </g>
# </svg>
# <div class="fontSize24 retailerColor inlineBox btnLabelPosition paddingLeft12">Order additional tags</div>
# </div>
# </a>
# </div>
# </div>
# </div>
# <br>
# <div class="tagBox grayBorder">
# <div class="tagDetailsModal hidden tagDetailsModal-sydney" id="modal-0" onclick="closeModal(0)">
# <div class="modal-content tagDetailsModalContent">
# <center class="modal-content-row retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" onclick="javascript: orderReplacementTag(event, 0,'','', 'CAR')" type="submit" value="This tag is not beeping"/>
# </center>
# <center class="modal-content-row modal-content-second retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportaslost/selectetag/sydney" id="reportlostlink" name="reportlostlink" onclick="javascript: populateIndex(0,'','')" type="submit" value="This tag is lost or stolen">
# <script>
# 													 $("#paymentServiceOutage-0").click(function(e) {
# 															 modalPopup();
# 													  });
#
# 													$(".okButton").click(function(e) {
# 														 $.fancybox.close();
# 														});
#
# 												function modalPopup(){
# 													invokeServiceOutageModal_AA("Payment Service");
# 														  jQuery.fancybox({
# 																	  href: "#confirmCancelPromptserviceoutage-0",
# 																	  padding: 30,
# 																	  width: 580,
# 																	  height: 300,
# 																	  autoSize:false,
# 																	  closeClick  : false, // prevents closing when clicking INSIDE fancybox
# 																	   helpers: {
# 																				overlay: {
# 																					closeClick: false
# 																				}
# 																				},
# 																	  tpl: {
# 																		 closeBtn : '<a class="popup-close" href="javascript:;"></a>'
# 																	  }
# 																	});
# 													}
#
#
# 												</script>
# </input></center>
# <center class="modal-content-row modal-content-second">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" type="button" value="Cancel"/>
# </center>
# </div>
# </div>
# <div class="tagDetailsBox">
# <div class="marginTop12">
# <div class="inlineBox">
# <div>
# 								Tag serial number</div>
# <b>0005458524</b>
# </div>
# <div class="inlineBox fr">
# <img height="60px" src="/retailweb/resources/common/img/NQFREE.svg" width="90px">
# </img></div>
# </div>
# <!-- GEM 1985 - Updating the Tag Tile [START]-->
# <div class="marginTop24" id="lastdetectedinfo-0">
# <div class="inlineBox">
# <div>
# 											Last known plate</div>
# <b>
# 													20/04/2021</b>
# </div>
# <div class="inlineBox fr">
# <div class="tagOuterPlate">
# <div class="tagInnerPlate">
# <center class="tagPlateState">NSW</center>
# <center class="tagPlateRego">CH32FV</center>
# </div>
# </div>
# </div>
# </div>
# <!--  GEM 1985 - Updating the Tag Tile [END]-->
# <div class="clearfix"></div>
# <div class="paddingTop24 paddingBottom12">
# 						Tag class<b class="marginLeft12">CAR</b>
# </div>
# <div class="paddingBottom12">
# 							Payment option<b class="marginLeft12">Deposit</b>
# </div>
# </div>
# <center class="retailerColor tagButton" onclick="javascript: orderAdditionalHolder(0)">
# <input class="transparentNone middle-valign" id="orderadditionalholder" name="orderadditionalholder" onclick="javascript: populateIndex(0,'','')" type="submit" value="Additional holders"/>
# <svg class="middle-valign" height="25px" version="1.1" viewbox="0 0 96 96" width="25px">
# <g fill="none" fill-rule="evenodd" id="Icons" stroke="none" stroke-width="1">
# <g fill="#14a248" id="icon-add-card">
# <g id="A/Icon/Add">
# <path d="M48,0 C21.4911618,0 0,21.4911618 0,48 C0,74.5088382 21.4911618,96 48,96 C74.5088382,96 96,74.5088382 96,48 C96,21.4911618 74.5088382,0 48,0 L48,0 Z M75.4289894,51.4289894 L51.4289894,51.4289894 L51.4289894,75.4289894 L44.5710106,75.4289894 L44.5710106,51.4289894 L20.5710106,51.4289894 L20.5710106,44.5710106 L44.5710106,44.5710106 L44.5710106,20.5710106 L51.4289894,20.5710106 L51.4289894,44.5710106 L75.4289894,44.5710106 L75.4289894,51.4289894 Z" id="Page-1"></path>
# </g>
# </g>
# </g>
# </svg>
# </center>
# <center class="retailerColor tagButton" onclick="javascript: showModal(0)">
# <input class="transparentNone middle-valign" id="reportlostlink" name="reportlostlink" style="outline:none;" type="button" value="Report issue"/>
# <svg class="middle-valign" height="25px" viewbox="0 0 24 24" width="25px">
# <path d="M12.776 14.41l.445-9.056h-2.459l.466 9.056h1.548zm-.779 1.487a1.205 1.205 0 0 0-1.335 1.346c-.042.376.071.752.313 1.043.272.256.64.385 1.012.353.375.038.746-.096 1.012-.364.242-.279.366-.642.344-1.01a1.374 1.374 0 0 0-.334-1.013 1.277 1.277 0 0 0-1.012-.355zM12 1.772C6.36 1.772 1.772 6.36 1.772 12S6.36 22.227 12 22.227 22.227 17.64 22.227 12C22.227 6.36 17.64 1.772 12 1.772zM12 24C5.383 24 0 18.616 0 12S5.383 0 12 0c6.616 0 12 5.384 12 12s-5.384 12-12 12z" fill="#14a248" fill-rule="evenodd"></path>
# </svg>
# </center>
# <input id="vehicleAssociatedWithin24Hr_0" name="vehicleAssociatedWithin24Hr_0" type="hidden" value=""/>
# </div>
# <script>
# 			if('Active' == 'Active' ) {
# 				if( ''.length > 0) {
# 					$('#etagDeallocateRego-'+'0').show();
# 				} else {
# 					$('#etagAddAllocateRego-'+'0').show();
# 				}
# 			}
#
# 			</script>
# <div class="tagBox grayBorder">
# <div class="tagDetailsModal hidden tagDetailsModal-sydney" id="modal-1" onclick="closeModal(1)">
# <div class="modal-content tagDetailsModalContent">
# <center class="modal-content-row retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" onclick="javascript: orderReplacementTag(event, 1,'','', 'CAR')" type="submit" value="This tag is not beeping"/>
# </center>
# <center class="modal-content-row modal-content-second retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportaslost/selectetag/sydney" id="reportlostlink" name="reportlostlink" onclick="javascript: populateIndex(1,'','')" type="submit" value="This tag is lost or stolen">
# <script>
# 													 $("#paymentServiceOutage-1").click(function(e) {
# 															 modalPopup();
# 													  });
#
# 													$(".okButton").click(function(e) {
# 														 $.fancybox.close();
# 														});
#
# 												function modalPopup(){
# 													invokeServiceOutageModal_AA("Payment Service");
# 														  jQuery.fancybox({
# 																	  href: "#confirmCancelPromptserviceoutage-1",
# 																	  padding: 30,
# 																	  width: 580,
# 																	  height: 300,
# 																	  autoSize:false,
# 																	  closeClick  : false, // prevents closing when clicking INSIDE fancybox
# 																	   helpers: {
# 																				overlay: {
# 																					closeClick: false
# 																				}
# 																				},
# 																	  tpl: {
# 																		 closeBtn : '<a class="popup-close" href="javascript:;"></a>'
# 																	  }
# 																	});
# 													}
#
#
# 												</script>
# </input></center>
# <center class="modal-content-row modal-content-second">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" type="button" value="Cancel"/>
# </center>
# </div>
# </div>
# <div class="tagDetailsBox">
# <div class="marginTop12">
# <div class="inlineBox">
# <div>
# 								Tag serial number</div>
# <b>0005458526</b>
# </div>
# <div class="inlineBox fr">
# <img height="60px" src="/retailweb/resources/common/img/NQFREE.svg" width="90px"/>
# </div>
# </div>
# <!-- GEM 1985 - Updating the Tag Tile [START]-->
# <div class="marginTop24" id="lastdetectedinfo-1">
# <div class="inlineBox">
# <div>
# 											Last known plate</div>
# <b>
# 													20/04/2021</b>
# </div>
# <div class="inlineBox fr">
# <div class="tagOuterPlate">
# <div class="tagInnerPlate">
# <center class="tagPlateState">NSW</center>
# <center class="tagPlateRego">CQ64LO</center>
# </div>
# </div>
# </div>
# </div>
# <!--  GEM 1985 - Updating the Tag Tile [END]-->
# <div class="clearfix"></div>
# <div class="paddingTop24 paddingBottom12">
# 						Tag class<b class="marginLeft12">CAR</b>
# </div>
# <div class="paddingBottom12">
# 							Payment option<b class="marginLeft12">Deposit</b>
# </div>
# </div>
# <center class="retailerColor tagButton" onclick="javascript: orderAdditionalHolder(1)">
# <input class="transparentNone middle-valign" id="orderadditionalholder" name="orderadditionalholder" onclick="javascript: populateIndex(1,'','')" type="submit" value="Additional holders"/>
# <svg class="middle-valign" height="25px" version="1.1" viewbox="0 0 96 96" width="25px">
# <g fill="none" fill-rule="evenodd" id="Icons" stroke="none" stroke-width="1">
# <g fill="#14a248" id="icon-add-card">
# <g id="A/Icon/Add">
# <path d="M48,0 C21.4911618,0 0,21.4911618 0,48 C0,74.5088382 21.4911618,96 48,96 C74.5088382,96 96,74.5088382 96,48 C96,21.4911618 74.5088382,0 48,0 L48,0 Z M75.4289894,51.4289894 L51.4289894,51.4289894 L51.4289894,75.4289894 L44.5710106,75.4289894 L44.5710106,51.4289894 L20.5710106,51.4289894 L20.5710106,44.5710106 L44.5710106,44.5710106 L44.5710106,20.5710106 L51.4289894,20.5710106 L51.4289894,44.5710106 L75.4289894,44.5710106 L75.4289894,51.4289894 Z" id="Page-1"></path>
# </g>
# </g>
# </g>
# </svg>
# </center>
# <center class="retailerColor tagButton" onclick="javascript: showModal(1)">
# <input class="transparentNone middle-valign" id="reportlostlink" name="reportlostlink" style="outline:none;" type="button" value="Report issue"/>
# <svg class="middle-valign" height="25px" viewbox="0 0 24 24" width="25px">
# <path d="M12.776 14.41l.445-9.056h-2.459l.466 9.056h1.548zm-.779 1.487a1.205 1.205 0 0 0-1.335 1.346c-.042.376.071.752.313 1.043.272.256.64.385 1.012.353.375.038.746-.096 1.012-.364.242-.279.366-.642.344-1.01a1.374 1.374 0 0 0-.334-1.013 1.277 1.277 0 0 0-1.012-.355zM12 1.772C6.36 1.772 1.772 6.36 1.772 12S6.36 22.227 12 22.227 22.227 17.64 22.227 12C22.227 6.36 17.64 1.772 12 1.772zM12 24C5.383 24 0 18.616 0 12S5.383 0 12 0c6.616 0 12 5.384 12 12s-5.384 12-12 12z" fill="#14a248" fill-rule="evenodd"></path>
# </svg>
# </center>
# <input id="vehicleAssociatedWithin24Hr_1" name="vehicleAssociatedWithin24Hr_1" type="hidden" value=""/>
# </div>
# <script>
# 			if('Active' == 'Active' ) {
# 				if( ''.length > 0) {
# 					$('#etagDeallocateRego-'+'1').show();
# 				} else {
# 					$('#etagAddAllocateRego-'+'1').show();
# 				}
# 			}
#
# 			</script>
# <div class="tagBox grayBorder">
# <div class="tagDetailsModal hidden tagDetailsModal-sydney" id="modal-2" onclick="closeModal(2)">
# <div class="modal-content tagDetailsModalContent">
# <center class="modal-content-row retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" onclick="javascript: orderReplacementTag(event, 2,'','', 'CAR')" type="submit" value="This tag is not beeping"/>
# </center>
# <center class="modal-content-row modal-content-second retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportaslost/selectetag/sydney" id="reportlostlink" name="reportlostlink" onclick="javascript: populateIndex(2,'','')" type="submit" value="This tag is lost or stolen">
# <script>
# 													 $("#paymentServiceOutage-2").click(function(e) {
# 															 modalPopup();
# 													  });
#
# 													$(".okButton").click(function(e) {
# 														 $.fancybox.close();
# 														});
#
# 												function modalPopup(){
# 													invokeServiceOutageModal_AA("Payment Service");
# 														  jQuery.fancybox({
# 																	  href: "#confirmCancelPromptserviceoutage-2",
# 																	  padding: 30,
# 																	  width: 580,
# 																	  height: 300,
# 																	  autoSize:false,
# 																	  closeClick  : false, // prevents closing when clicking INSIDE fancybox
# 																	   helpers: {
# 																				overlay: {
# 																					closeClick: false
# 																				}
# 																				},
# 																	  tpl: {
# 																		 closeBtn : '<a class="popup-close" href="javascript:;"></a>'
# 																	  }
# 																	});
# 													}
#
#
# 												</script>
# </input></center>
# <center class="modal-content-row modal-content-second">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" type="button" value="Cancel"/>
# </center>
# </div>
# </div>
# <div class="tagDetailsBox">
# <div class="marginTop12">
# <div class="inlineBox">
# <div>
# 								Tag serial number</div>
# <b>0005458310</b>
# </div>
# <div class="inlineBox fr">
# <img height="60px" src="/retailweb/resources/common/img/NQFREE.svg" width="90px"/>
# </div>
# </div>
# <!-- GEM 1985 - Updating the Tag Tile [START]-->
# <div class="marginTop24" id="lastdetectedinfo-2">
# <div class="inlineBox">
# <div>
# 											Last known plate</div>
# <b>Unknown</b>
# </div>
# </div>
# <!--  GEM 1985 - Updating the Tag Tile [END]-->
# <div class="clearfix"></div>
# <div class="paddingTop24 paddingBottom12">
# 						Tag class<b class="marginLeft12">CAR</b>
# </div>
# <div class="paddingBottom12">
# 							Payment option<b class="marginLeft12">Deposit</b>
# </div>
# </div>
# <center class="retailerColor tagButton" onclick="javascript: orderAdditionalHolder(2)">
# <input class="transparentNone middle-valign" id="orderadditionalholder" name="orderadditionalholder" onclick="javascript: populateIndex(2,'','')" type="submit" value="Additional holders"/>
# <svg class="middle-valign" height="25px" version="1.1" viewbox="0 0 96 96" width="25px">
# <g fill="none" fill-rule="evenodd" id="Icons" stroke="none" stroke-width="1">
# <g fill="#14a248" id="icon-add-card">
# <g id="A/Icon/Add">
# <path d="M48,0 C21.4911618,0 0,21.4911618 0,48 C0,74.5088382 21.4911618,96 48,96 C74.5088382,96 96,74.5088382 96,48 C96,21.4911618 74.5088382,0 48,0 L48,0 Z M75.4289894,51.4289894 L51.4289894,51.4289894 L51.4289894,75.4289894 L44.5710106,75.4289894 L44.5710106,51.4289894 L20.5710106,51.4289894 L20.5710106,44.5710106 L44.5710106,44.5710106 L44.5710106,20.5710106 L51.4289894,20.5710106 L51.4289894,44.5710106 L75.4289894,44.5710106 L75.4289894,51.4289894 Z" id="Page-1"></path>
# </g>
# </g>
# </g>
# </svg>
# </center>
# <center class="retailerColor tagButton" onclick="javascript: showModal(2)">
# <input class="transparentNone middle-valign" id="reportlostlink" name="reportlostlink" style="outline:none;" type="button" value="Report issue"/>
# <svg class="middle-valign" height="25px" viewbox="0 0 24 24" width="25px">
# <path d="M12.776 14.41l.445-9.056h-2.459l.466 9.056h1.548zm-.779 1.487a1.205 1.205 0 0 0-1.335 1.346c-.042.376.071.752.313 1.043.272.256.64.385 1.012.353.375.038.746-.096 1.012-.364.242-.279.366-.642.344-1.01a1.374 1.374 0 0 0-.334-1.013 1.277 1.277 0 0 0-1.012-.355zM12 1.772C6.36 1.772 1.772 6.36 1.772 12S6.36 22.227 12 22.227 22.227 17.64 22.227 12C22.227 6.36 17.64 1.772 12 1.772zM12 24C5.383 24 0 18.616 0 12S5.383 0 12 0c6.616 0 12 5.384 12 12s-5.384 12-12 12z" fill="#14a248" fill-rule="evenodd"></path>
# </svg>
# </center>
# <input id="vehicleAssociatedWithin24Hr_2" name="vehicleAssociatedWithin24Hr_2" type="hidden" value=""/>
# </div>
# <script>
# 			if('Active' == 'Active' ) {
# 				if( ''.length > 0) {
# 					$('#etagDeallocateRego-'+'2').show();
# 				} else {
# 					$('#etagAddAllocateRego-'+'2').show();
# 				}
# 			}
#
# 			</script>
# <div class="tagBox grayBorder">
# <div class="tagDetailsModal hidden tagDetailsModal-sydney" id="modal-3" onclick="closeModal(3)">
# <div class="modal-content tagDetailsModalContent">
# <center class="modal-content-row retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" onclick="javascript: orderReplacementTag(event, 3,'','', 'CAR')" type="submit" value="This tag is not beeping"/>
# </center>
# <center class="modal-content-row modal-content-second retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportaslost/selectetag/sydney" id="reportlostlink" name="reportlostlink" onclick="javascript: populateIndex(3,'','')" type="submit" value="This tag is lost or stolen">
# <script>
# 													 $("#paymentServiceOutage-3").click(function(e) {
# 															 modalPopup();
# 													  });
#
# 													$(".okButton").click(function(e) {
# 														 $.fancybox.close();
# 														});
#
# 												function modalPopup(){
# 													invokeServiceOutageModal_AA("Payment Service");
# 														  jQuery.fancybox({
# 																	  href: "#confirmCancelPromptserviceoutage-3",
# 																	  padding: 30,
# 																	  width: 580,
# 																	  height: 300,
# 																	  autoSize:false,
# 																	  closeClick  : false, // prevents closing when clicking INSIDE fancybox
# 																	   helpers: {
# 																				overlay: {
# 																					closeClick: false
# 																				}
# 																				},
# 																	  tpl: {
# 																		 closeBtn : '<a class="popup-close" href="javascript:;"></a>'
# 																	  }
# 																	});
# 													}
#
#
# 												</script>
# </input></center>
# <center class="modal-content-row modal-content-second">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" type="button" value="Cancel"/>
# </center>
# </div>
# </div>
# <div class="tagDetailsBox">
# <div class="marginTop12">
# <div class="inlineBox">
# <div>
# 								Tag serial number</div>
# <b>0005458311</b>
# </div>
# <div class="inlineBox fr">
# <img height="60px" src="/retailweb/resources/common/img/NQFREE.svg" width="90px"/>
# </div>
# </div>
# <!-- GEM 1985 - Updating the Tag Tile [START]-->
# <div class="marginTop24" id="lastdetectedinfo-3">
# <div class="inlineBox">
# <div>
# 											Last known plate</div>
# <b>
# 													20/04/2021</b>
# </div>
# <div class="inlineBox fr">
# <div class="tagOuterPlate">
# <div class="tagInnerPlate">
# <center class="tagPlateState">NSW</center>
# <center class="tagPlateRego">XN44QZ</center>
# </div>
# </div>
# </div>
# </div>
# <!--  GEM 1985 - Updating the Tag Tile [END]-->
# <div class="clearfix"></div>
# <div class="paddingTop24 paddingBottom12">
# 						Tag class<b class="marginLeft12">CAR</b>
# </div>
# </div>
# <center class="retailerColor tagButton" onclick="javascript: orderAdditionalHolder(3)">
# <input class="transparentNone middle-valign" id="orderadditionalholder" name="orderadditionalholder" onclick="javascript: populateIndex(3,'','')" type="submit" value="Additional holders"/>
# <svg class="middle-valign" height="25px" version="1.1" viewbox="0 0 96 96" width="25px">
# <g fill="none" fill-rule="evenodd" id="Icons" stroke="none" stroke-width="1">
# <g fill="#14a248" id="icon-add-card">
# <g id="A/Icon/Add">
# <path d="M48,0 C21.4911618,0 0,21.4911618 0,48 C0,74.5088382 21.4911618,96 48,96 C74.5088382,96 96,74.5088382 96,48 C96,21.4911618 74.5088382,0 48,0 L48,0 Z M75.4289894,51.4289894 L51.4289894,51.4289894 L51.4289894,75.4289894 L44.5710106,75.4289894 L44.5710106,51.4289894 L20.5710106,51.4289894 L20.5710106,44.5710106 L44.5710106,44.5710106 L44.5710106,20.5710106 L51.4289894,20.5710106 L51.4289894,44.5710106 L75.4289894,44.5710106 L75.4289894,51.4289894 Z" id="Page-1"></path>
# </g>
# </g>
# </g>
# </svg>
# </center>
# <center class="retailerColor tagButton" onclick="javascript: showModal(3)">
# <input class="transparentNone middle-valign" id="reportlostlink" name="reportlostlink" style="outline:none;" type="button" value="Report issue"/>
# <svg class="middle-valign" height="25px" viewbox="0 0 24 24" width="25px">
# <path d="M12.776 14.41l.445-9.056h-2.459l.466 9.056h1.548zm-.779 1.487a1.205 1.205 0 0 0-1.335 1.346c-.042.376.071.752.313 1.043.272.256.64.385 1.012.353.375.038.746-.096 1.012-.364.242-.279.366-.642.344-1.01a1.374 1.374 0 0 0-.334-1.013 1.277 1.277 0 0 0-1.012-.355zM12 1.772C6.36 1.772 1.772 6.36 1.772 12S6.36 22.227 12 22.227 22.227 17.64 22.227 12C22.227 6.36 17.64 1.772 12 1.772zM12 24C5.383 24 0 18.616 0 12S5.383 0 12 0c6.616 0 12 5.384 12 12s-5.384 12-12 12z" fill="#14a248" fill-rule="evenodd"></path>
# </svg>
# </center>
# <input id="vehicleAssociatedWithin24Hr_3" name="vehicleAssociatedWithin24Hr_3" type="hidden" value=""/>
# </div>
# <script>
# 			if('Active' == 'Active' ) {
# 				if( ''.length > 0) {
# 					$('#etagDeallocateRego-'+'3').show();
# 				} else {
# 					$('#etagAddAllocateRego-'+'3').show();
# 				}
# 			}
#
# 			</script>
# <div class="tagBox grayBorder">
# <div class="tagDetailsModal hidden tagDetailsModal-sydney" id="modal-4" onclick="closeModal(4)">
# <div class="modal-content tagDetailsModalContent">
# <center class="modal-content-row retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" onclick="javascript: orderReplacementTag(event, 4,'','', 'CAR')" type="submit" value="This tag is not beeping"/>
# </center>
# <center class="modal-content-row modal-content-second retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportaslost/selectetag/sydney" id="reportlostlink" name="reportlostlink" onclick="javascript: populateIndex(4,'','')" type="submit" value="This tag is lost or stolen">
# <script>
# 													 $("#paymentServiceOutage-4").click(function(e) {
# 															 modalPopup();
# 													  });
#
# 													$(".okButton").click(function(e) {
# 														 $.fancybox.close();
# 														});
#
# 												function modalPopup(){
# 													invokeServiceOutageModal_AA("Payment Service");
# 														  jQuery.fancybox({
# 																	  href: "#confirmCancelPromptserviceoutage-4",
# 																	  padding: 30,
# 																	  width: 580,
# 																	  height: 300,
# 																	  autoSize:false,
# 																	  closeClick  : false, // prevents closing when clicking INSIDE fancybox
# 																	   helpers: {
# 																				overlay: {
# 																					closeClick: false
# 																				}
# 																				},
# 																	  tpl: {
# 																		 closeBtn : '<a class="popup-close" href="javascript:;"></a>'
# 																	  }
# 																	});
# 													}
#
#
# 												</script>
# </input></center>
# <center class="modal-content-row modal-content-second">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" type="button" value="Cancel"/>
# </center>
# </div>
# </div>
# <div class="tagDetailsBox">
# <div class="marginTop12">
# <div class="inlineBox">
# <div>
# 								Tag serial number</div>
# <b>0005458312</b>
# </div>
# <div class="inlineBox fr">
# <img height="60px" src="/retailweb/resources/common/img/NQFREE.svg" width="90px"/>
# </div>
# </div>
# <!-- GEM 1985 - Updating the Tag Tile [START]-->
# <div class="marginTop24" id="lastdetectedinfo-4">
# <div class="inlineBox">
# <div>
# 											Last known plate</div>
# <b>
# 													15/04/2021</b>
# </div>
# <div class="inlineBox fr">
# <div class="tagOuterPlate">
# <div class="tagInnerPlate">
# <center class="tagPlateState">NSW</center>
# <center class="tagPlateRego">XN81VB</center>
# </div>
# </div>
# </div>
# </div>
# <!--  GEM 1985 - Updating the Tag Tile [END]-->
# <div class="clearfix"></div>
# <div class="paddingTop24 paddingBottom12">
# 						Tag class<b class="marginLeft12">CAR</b>
# </div>
# <div class="paddingBottom12">
# 							Payment option<b class="marginLeft12">Deposit</b>
# </div>
# </div>
# <center class="retailerColor tagButton" onclick="javascript: orderAdditionalHolder(4)">
# <input class="transparentNone middle-valign" id="orderadditionalholder" name="orderadditionalholder" onclick="javascript: populateIndex(4,'','')" type="submit" value="Additional holders"/>
# <svg class="middle-valign" height="25px" version="1.1" viewbox="0 0 96 96" width="25px">
# <g fill="none" fill-rule="evenodd" id="Icons" stroke="none" stroke-width="1">
# <g fill="#14a248" id="icon-add-card">
# <g id="A/Icon/Add">
# <path d="M48,0 C21.4911618,0 0,21.4911618 0,48 C0,74.5088382 21.4911618,96 48,96 C74.5088382,96 96,74.5088382 96,48 C96,21.4911618 74.5088382,0 48,0 L48,0 Z M75.4289894,51.4289894 L51.4289894,51.4289894 L51.4289894,75.4289894 L44.5710106,75.4289894 L44.5710106,51.4289894 L20.5710106,51.4289894 L20.5710106,44.5710106 L44.5710106,44.5710106 L44.5710106,20.5710106 L51.4289894,20.5710106 L51.4289894,44.5710106 L75.4289894,44.5710106 L75.4289894,51.4289894 Z" id="Page-1"></path>
# </g>
# </g>
# </g>
# </svg>
# </center>
# <center class="retailerColor tagButton" onclick="javascript: showModal(4)">
# <input class="transparentNone middle-valign" id="reportlostlink" name="reportlostlink" style="outline:none;" type="button" value="Report issue"/>
# <svg class="middle-valign" height="25px" viewbox="0 0 24 24" width="25px">
# <path d="M12.776 14.41l.445-9.056h-2.459l.466 9.056h1.548zm-.779 1.487a1.205 1.205 0 0 0-1.335 1.346c-.042.376.071.752.313 1.043.272.256.64.385 1.012.353.375.038.746-.096 1.012-.364.242-.279.366-.642.344-1.01a1.374 1.374 0 0 0-.334-1.013 1.277 1.277 0 0 0-1.012-.355zM12 1.772C6.36 1.772 1.772 6.36 1.772 12S6.36 22.227 12 22.227 22.227 17.64 22.227 12C22.227 6.36 17.64 1.772 12 1.772zM12 24C5.383 24 0 18.616 0 12S5.383 0 12 0c6.616 0 12 5.384 12 12s-5.384 12-12 12z" fill="#14a248" fill-rule="evenodd"></path>
# </svg>
# </center>
# <input id="vehicleAssociatedWithin24Hr_4" name="vehicleAssociatedWithin24Hr_4" type="hidden" value=""/>
# </div>
# <script>
# 			if('Active' == 'Active' ) {
# 				if( ''.length > 0) {
# 					$('#etagDeallocateRego-'+'4').show();
# 				} else {
# 					$('#etagAddAllocateRego-'+'4').show();
# 				}
# 			}
#
# 			</script>
# <div class="tagBox grayBorder">
# <div class="tagDetailsModal hidden tagDetailsModal-sydney" id="modal-5" onclick="closeModal(5)">
# <div class="modal-content tagDetailsModalContent">
# <center class="modal-content-row retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" onclick="javascript: orderReplacementTag(event, 5,'','', 'HCV')" type="submit" value="This tag is not beeping"/>
# </center>
# <center class="modal-content-row modal-content-second retailerColor">
# <input class="transparentNone" formaction="/retailweb/tags/reportaslost/selectetag/sydney" id="reportlostlink" name="reportlostlink" onclick="javascript: populateIndex(5,'','')" type="submit" value="This tag is lost or stolen">
# <script>
# 													 $("#paymentServiceOutage-5").click(function(e) {
# 															 modalPopup();
# 													  });
#
# 													$(".okButton").click(function(e) {
# 														 $.fancybox.close();
# 														});
#
# 												function modalPopup(){
# 													invokeServiceOutageModal_AA("Payment Service");
# 														  jQuery.fancybox({
# 																	  href: "#confirmCancelPromptserviceoutage-5",
# 																	  padding: 30,
# 																	  width: 580,
# 																	  height: 300,
# 																	  autoSize:false,
# 																	  closeClick  : false, // prevents closing when clicking INSIDE fancybox
# 																	   helpers: {
# 																				overlay: {
# 																					closeClick: false
# 																				}
# 																				},
# 																	  tpl: {
# 																		 closeBtn : '<a class="popup-close" href="javascript:;"></a>'
# 																	  }
# 																	});
# 													}
#
#
# 												</script>
# </input></center>
# <center class="modal-content-row modal-content-second">
# <input class="transparentNone" formaction="/retailweb/tags/reportfaulty/sydney" id="reportfaultylink" name="reportfaultylink" type="button" value="Cancel"/>
# </center>
# </div>
# </div>
# ...
# 						etagSerialNumber : etagSerialNumber,
# 						pageResponse : pageResponse
# 					}),
# 					success : function(response) {
# 						$('#error').remove();
# 						if (response == 'success') {
# 							showInPopup('sendSuccess');
# 						} else {
# 							$(
# 									"<div id='error' class='errorblock'><p>Email address entered is invalid!</p></div>")
# 									.insertBefore('#emailForm');
# 						}
# 					}
# 				});
# 	}
# </script><!-- Debug - 'base' -->
# <!--  GLIDEB-1278 ###### Header/Footer Changes- [START] ####### -->
# <div class="footer disableFromPrint">
# <div class="l-padding cf">
# <div class="footer__logo-container">
# <div class="text">
# 									Owner and manager</div>
# <a href="http://www.transurban.com.au">
# <img alt="Transurban logo" class="logo" src="/retailweb/resources/common/img/logo-Transurban.png"/>
# </a>
# </div>
# <div class="footer__content-container cf">
# <div class="footer__links fn_footer__links link-icons-disabled cf">
# <ul>
# <li>
# <a class="fn_footer__link" href="javascript:openContentPage('legal/policies/terms-of-use', 'Footer','Terms of use');">Terms of use</a>
# </li>
# <li>
# <a class="fn_footer__link" href="javascript:openContentPage('legal/policies/transurban-privacy-policy', 'Footer','Privacy');">Privacy</a>
# </li>
# <li>
# <a class="fn_footer__link" href="javascript:openContentPage('contact-us', 'Footer','Contact us');">Contact us</a>
# </li>
# <li>
# <a class="fn_footer__link" href="javascript:openContentPage('help', 'Footer','Help');">Help</a>
# </li>
# <li>
# <a class="fn_footer__link" href="javascript:openContentPage('about-us', 'Footer','About us');">About us</a>
# </li>
# </ul>
# </div>
# <div class="footer__copy">
# 									Linkt and Linkt Sydney are trade marks of Transurban Limited used under licence by Tollaust Pty Ltd ABN 37 050 538 693.<br>
# </br></div>
# </div>
# <div class="footer__social-links-container">
# <div class="section">
# <div class="module module--social-links">
# <div class="module__content l-full-width">
# <div class="social-links">
# <ul class="social-links__list">
# <li>
# <a class="social-links__link" href="http://twitter.com/linktsydney" target="_blank">
# <img alt="Linkt Twitter" class="icon" src="/retailweb/resources/retailer/linkt/img/icons/icon-twitter.png"/>
# <span class="text">twitter</span>
# </a>
# </li>
# <li>
# <a class="social-links__link" href="https://www.facebook.com/TransurbanLinkt/" target="_blank">
# <img alt="Linkt Facebook" class="icon" src="/retailweb/resources/retailer/linkt/img/icons/facebook-icon.png"/>
# <span class="text">facebook</span>
# </a>
# </li>
# <li>
# <a class="social-links__link" href="https://www.youtube.com/channel/UCVdVDFxM_Da7Enjysd1TzoA" target="_blank">
# <img alt="Linkt Youtube" class="icon" src="/retailweb/resources/retailer/linkt/img/icons/icon-youtube.png"/>
# <span class="text">youtube</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
#
# <script>
# function openContentPage(subpath, navigationBarLocation, linkName){
#
# 	if(navigationBarLocation != null && navigationBarLocation != undefined && navigationBarLocation != '' && linkName != null && linkName != undefined && linkName != '')
# 	{
# 		invokeNavigationBar_AA('authenticatedTopNav', navigationBarLocation, linkName);
# 	}
#
# 	redirectToCMSSite(subpath, true, "https://www.linkt.com.au/", "new", "https://www.linkt.com.au/sydney");
#
# }
#
# function checkUserCredentails(){
#
#
#   	$("input#ssname").val("craig");
# 	$("input#ssclass").val("logged-in");
#
#
# }
# </script><!--  GLIDEB-1278 ###### Header/Footer Changes- [END] ####### -->
# <div id="segmentationDataDiv"></div>
# <input id="tuCookieName1" type="hidden" value="tu_sgl">
# <input id="tuCookieName2" type="hidden" value="tu_sga">
# <input id="tuCookieName3" type="hidden" value="tu_sgp">
# <input id="customer" type="hidden" value="">
# <input id="retailerBrand" type="hidden" value="">
# <input id="accountType" type="hidden" value="">
# <input id="accountStatus" type="hidden" value="">
# <input id="marketingSegment" type="hidden" value="">
# <input id="autoPayment" type="hidden" value="">
# <input id="paperless" type="hidden" value="">
# <input id="uniqueID" type="hidden" value="">
# <input id="userFirstName" type="hidden" value="">
# <input id="lastLogin" type="hidden" value="">
# <input id="passPurchase" type="hidden" value="">
# <input id="loginCookie" type="hidden" value="">
# <input id="accountInfoCookie" type="hidden" value="">
# <input id="passCookie" type="hidden" value="">
# <input id="crossDomainURL" type="hidden" value="">
# <input id="passesCrossDomainURL" type="hidden" value="">
# <input id="passCookieMyAct" type="hidden" value="">
# <script>
# $(function() {
# 	if($('#loginCookie').val() == 'true')
# 	{
# 		var segmentDataCookieObj={};
# 		segmentDataCookieObj._cn = $('#tuCookieName1').val();
# 		segmentDataCookieObj._cu = $('#customer').val();
# 		segmentDataCookieObj._rb = $('#retailerBrand').val();
# 		segmentDataCookieObj._at = $('#accountType').val();
# 		segmentDataCookieObj._ms = $('#marketingSegment').val();
# 		segmentDataCookieObj._pl = $('#paperless').val();
# 		segmentDataCookieObj._uid = $('#uniqueID').val();
# 		//segmentDataCookieObj._fn = $('#userFirstName').val();
# 		segmentDataCookieObj._ll = $('#lastLogin').val();
#
# 		var jsonCookieStr = JSON.stringify(segmentDataCookieObj);
# 		sendCrossDomainCookie(jsonCookieStr);
# 	}
#
# 	if($('#accountInfoCookie').val() == 'true')
# 	{
# 		var segmentDataCookieObj={};
# 		segmentDataCookieObj._cn = $('#tuCookieName2').val();
# 		segmentDataCookieObj._as = $('#accountStatus').val();
# 		segmentDataCookieObj._ap = $('#autoPayment').val();
#
# 		var jsonCookieStr = JSON.stringify(segmentDataCookieObj);
# 		sendCrossDomainCookie(jsonCookieStr);
# 	}
#
# 	if($('#passCookie').val() == 'true' || $('#passCookieMyAct').val() == 'true')
# 	{
# 		var segmentDataCookieObj={};
# 		segmentDataCookieObj._cn = $('#tuCookieName3').val();
# 		segmentDataCookieObj._pp = 'true';
#
# 		var jsonCookieStr = JSON.stringify(segmentDataCookieObj);
# 		sendCrossDomainCookie(jsonCookieStr);
# 	}
# });
#
# function sendCrossDomainCookie(jsonCookieStr){
#
# 	var jsonCookieObj = JSON.parse(jsonCookieStr);
# 	var requestParams = Object.keys(jsonCookieObj).map(function(key){
# 	  return encodeURIComponent(key) + '=' + encodeURIComponent(jsonCookieObj[key]);
# 	}).join('&');
#
#
# }
# function sendReqURL(eachURLVal, requestParams){
# 	var completeUrl = eachURLVal+"?"+requestParams;
# 	var img = $('<img style="display:none;">'); //Equivalent: $(document.createElement('img'))
# 	img.attr('src', completeUrl);
# 	img.appendTo('#segmentationDataDiv');
# }
# // [END] :: GEM-482 - Enh142 - iGLIDe - DEV - Capture and store segmentation data
# </script><input id="pageIdentifier" type="hidden" value="null">
# <input id="retailerCode" name="retailerCode" type="hidden" value="sydney">
# <input id="gtmAccountName" name="gtmAccountName" type="hidden" value="GTM-MNXQBG7">
# <input id="accountStatusDescription" name="accountStatusDescription" type="hidden" value="VALIDARRANGE">
# <!-- Google Tag Manager : START  -->
# <noscript>
# <iframe height="0" src="$(gtmURL)?id=$('#gtmAccountName')" style="display: none; visibility: hidden" width="0"></iframe>
# </noscript>
# <!-- Google Tag Manager : END  -->
# <script>
#
# $(document).ready(function() {
# 	<!-- Google Tag Manager : START  -->
# 	// Default and Mandatory Code to Invoke Google Tag Manager
# 	( function(w,d,s,l) {
#
# 		//alert('First GTM Call Cookie='+document.cookie);
#
# 		// Step1: [Ecommerce Page Flow Check] The below to code handle Ecommerce Flow Check
# 		var isFlowFromEcommerce = $('#flowFromEcommercePage').val();
# 		if(isFlowFromEcommerce == "true") {
# 			//Dont execute GTM, as this Flow call from Page
# 			//alert('Dont execute GTM, as this Flow call from Page');
# 			return;
# 		}
#
# 		// Step2: [Successful Login Check] Code checks for Cookie has USERLOGGEDIN Attribute or not.
# 		var cookies = document.cookie;
# 		if(cookies.indexOf("USERLOGGEDIN=True") >= 0) {
#
# 			// Invole GTM for Login Success Event
# 			invokeGTMForSuccessfulLogin();
#
# 			//Remove USERLOGGEDIN from Cookie
# 			//The below code for Firefox
# 			document.cookie='USERLOGGEDIN=; path=' + gblIgAppCxtPath + '/; expires=' + new Date(0).toUTCString();
# 			//The below code for Chrome & IE
# 			document.cookie='USERLOGGEDIN=; path=' + gblIgAppCxtPath + '; expires=' + new Date(0).toUTCString();
#
# 			//alert('Cookies After Update='+document.cookie);
# 			return;
# 		}
#
# 		// Step3: [Web Flow Check] The below code executes only for Spring Web Flow
# 		var pageId = $('#pageIdentifier').val();
# 		if(pageId != null && pageId != 'null' && pageId != '') {
#
# 			//Remove Query Parameters from Page URL
# 			var url = w.location.href.split('?')[0];
#
# 			//Remove Domain and Protocal Details from URL
# 			url = url.substring(url.indexOf(gblIgAppCxtPath), url.length);
#
# 			//Add Page Identification at end of the URL
# 			var pageURL = url + '/' + pageId;
#
# 			//alert(pageURL);
#
# 			// Setup Window Data Layer
# 			window.dataLayer = window.dataLayer || [];
#
# 			if (pageId.toUpperCase().indexOf("RECEIPT") >= 0) {
# 				var accountId = $('#accountId').val();
# 				var payReceiptId = $('#payReceiptId').val();
# 				var receiptAmount = $('#receiptAmount').val();
# 				var accountType = $('#accountType').val();
# 				var etagQuantity = $('#etagQuantity').val();
# 				var etagType = $('#etagType').val();
#
# 				invokeGTMEcommercePush(pageId, pageURL, accountType, accountType, receiptAmount, 'OPEN_ACCOUNT_SIGNUP', accountType, accountType, 'OPEN_ACCOUNT_SIGNUP', etagType, etagQuantity, accountType,'VirtualPageview');
# 			} else {
# 				invokeGTMPush(pageURL, pageId);
# 				invokeOpenAccountFlow($('#accountType').val());
# 			}
#
# 		}
#
# 		//Invoke Google Tag Manager
# 		executeGTM(w,d,s,l);
#
# 	} ) (window, document, 'script', 'dataLayer');
# });
#
#
# 	//This method to Invokes Google Tag Manager
# 	function executeGTM(w,d,s,l){
# 		//alert('executeGTM For Account-'+$('#gtmAccountName').val());
#
# 		w[l]=w[l]||[];
# 		w[l].push({'gtm.start':new Date().getTime(), event:'gtm.js'});
# 		var f=d.getElementsByTagName(s)[0], j=d.createElement(s), dl=l!='dataLayer'?'&l='+l:'';
# 		j.async=true;
# 		//j.src=$('#gtmURL').val()+'?id='+$('#gtmAccountName').val()+dl;
# 		j.src='https://www.googletagmanager.com/gtm.js?id='+$('#gtmAccountName').val()+dl;
# 		f.parentNode.insertBefore(j,f);
# 	}
#
# 	// This method is to Invoke GTM push (This invokes during spring web flows)
# 	function invokeGTMPush(pageURL, pageId) {
# 		//alert('invokeGTMPush');
#
# 		// The GTM push invokes for All Spring Web Flows except for Receipts
# 		dataLayer.push({
# 			'event'				:	'VirtualPageview',
# 			'virtualPageURL'	:	pageURL,
# 			'virtualPageTitle' 	: 	pageId,
# 		});
# 	}
#
# 	// This method is to Invoke GTB Ecommerce PUSH
# 	function invokeGTMEcommercePush(title, pageURL, id, aff, amt, act, pName, pId, pCat, pVari, pQuant, accountType, eventType) {
#
# 		if(pVari == 'true') {
# 			pVari = "Deposit-Etag";
# 		} else if(pVari == 'false') {
# 			pVari = "Lease-Etag";
# 		}
# 		else if (pVari == null ||  pVari == 'No ETAG'){
# 			pVari = "No ETAG";
# 		}
#
# 		if (pQuant == null || pQuant == '0'){
# 			pQuant = '1';
# 		}
#
#
# 		//alert('invokeGTMEcommercePush title='+title+'& id='+id+'& aff='+aff+'& amt='+amt+'& act='+act+'& pName='+pName+'& pId='+pId+'& pCat='+pCat+'& pVari='+pVari+'& pQuant='+pQuant+'& accountType='+accountType+'& eventType='+eventType);
# 		// Populate Value Dynamicaly
# 		// The GTM push invokes for only Receipt Scenarios
# 		dataLayer.push({
# 			'event'				:	eventType,
# 			'virtualPageURL'	:	pageURL,
# 			'virtualPageTitle' 	: 	title,
# 			'ecommerce': {
# 				'purchase': {
# 					'actionField': {
# 						id			: accountType, 								// SKU Number Ex. MELBOURNE_ET_AC, 24hour/tulla/weekend/access/everyday/commercial/melbourne/consumeretag/commercialetag/visitorepss
# 						affiliation	: aff, 										// Description Ex. Everyday_Account_Signup
# 						revenue		: amt, 										// Total Amount purchasing Ex. 50.00
# 						action		: act	 									// purchase action Ex. SignUp, buyPass, makepayment
# 					},
# 					'products': [{
# 						'name'		: accountType, 								// (product Type)
# 						'id'		: pId, 										// product SKU in analytics reports Ex. 112233
# 						'price'		: amt, 										// Total payment amount Ex. 50.00
# 						'brand'		: $('#retailerCode').val().toUpperCase(), 	// Brand Ex. Citylink
# 						'category'	: pCat, 									// Category Ex. SignUp, buyPass, makepayment
# 						'variant'	: pVari, 									// tag type or Ex. deposit-tag
# 						'quantity'	: pQuant 									// Ex. 10
# 					}]
# 				},
# 			},
# 		});
#
# 		//alert('invokeGTMEcommercePush end');
# 	}
#
# 	// This is Helper method to Invoke GTB Ecommerce PUSH
# 	function receiptGTMEcommerce(accountType, id, aff, amt, act, pName, pId, pCat, pVari, pQuant,eventType ) {
# 		//alert('receiptGTMEcommerce');
#
# 		//Remove Query Parameters from Page URL
# 		var url = window.location.href.split('?')[0];
#
# 		// Setup Window Data Layer
# 		window.dataLayer = window.dataLayer || [];
#
# 		invokeGTMEcommercePush('', '', id, aff, amt, act, pName, pId, pCat, pVari, pQuant, accountType,eventType);
#
# 		//alert('invokeGTMEcommercePush after');
#
# 		executeGTM(window, document, 'script', 'dataLayer');
# 	}
#
#
# 	// This method is to Invoke Login Success events
# 	function invokeGTMForSuccessfulLogin() {
#
# 		// The GTM push invokes for only Receipt Scenarios
# 		window.dataLayer = window.dataLayer || [];
# 		dataLayer.push({
# 			'event'				:	'loginSuccess'
# 		});
#
# 		executeGTM(window, document, 'script', 'dataLayer');
#
# 		// GLIDEB-1149 Adobe analytics MVP2: Track account login success
# 		if(true === true)
# 		{
# 			invokeAccountLoginSuccess( $('#accountStatusDescription').val());
# 		}
# 	}
#
# 	<!-- End Google Tag Manager : END -->
#
# </script>
# <!-- Adobe Analytics : START  -->
# <script type="text/javascript"> $(document ).ready(function() { _satellite.pageBottom(); });</script>
# <!-- Adobe Analytics : END  -->
# <script defer="" src="/retailweb/resources/vendor/jquery/jquery.validate.min.js"></script>
# <script src="/retailweb/resources/vendor/fancybox/jquery.fancybox.pack.js"></script>
# <script defer="" src="/retailweb/resources/vendor/jquery/additional-methods.min.js"></script>
# <script defer="" src="/retailweb/resources/vendor/jquery/CSSPlugin.min.js"></script>
# <script defer="" src="/retailweb/resources/vendor/jquery/EasePack.min.js"></script>
# <script defer="" src="/retailweb/resources/vendor/jquery/TweenLite.min.js"></script>
# <script defer="" src="/retailweb/resources/vendor/jquery/TimelineLite.min.js"></script>
# <script defer="" src="/retailweb/resources/vendor/jquery/ScrollToPlugin.min.js"></script>
# <script defer="" src="/retailweb/resources/vendor/jquery/waypoints.min.js"></script>
# <script defer="" src="/retailweb/resources/common/js/plugins.js"></script>
# <script src="/retailweb/resources/common/js/printThis.js"></script>
# <script src="/retailweb/resources/vendor/footable/footable.js"></script>
# <script src="/retailweb/resources/vendor/footable/footable.sort.js"></script>
# <script src="/retailweb/resources/vendor/footable/footable.paginate.js"></script>
# <script src="/retailweb/resources/vendor/footable/footable.filter.js"></script>
# <script src="/retailweb/resources/vendor/jquery/jquery.highlight.js"></script>
# <script src="/retailweb/resources/common/js/iglide-common-validator.js"></script>
# <script src="/retailweb/resources/retailer/linkt/js/main.js"></script>
# <script src="/retailweb/resources/retailer/linkt/js/account.js"></script>
# <script src="/retailweb/resources/common/js/iglide-menu.js"></script>
# <!-- [Start]: Elev IO Section - BMR1124 -->
# <script>
# 	var _elev = window._elev || {};(function() {var i,e;i=document.createElement("script"),i.type='text/javascript';i.async=1,i.src="https://static.elev.io/js/v3.js",e=document.getElementsByTagName("script")[0],e.parentNode.insertBefore(i,e);})();
# 	_elev.account_id = '57be985044984';
# </script>
# <!-- [End]: Elev IO Section - BMR1124 -->
# <input id="version" name="version" type="hidden" value="IGLIDE_R21_5_3_0003">
# </input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></body>
# </html>

# %%
for item in soup.find_all("div", class_="tagDetailsBox"):
        row = []
        tag_serial_number = np.nan
        date_last_known_plate = np.nan
        tag_class = np.nan
        state = np.nan
        number_plate = np.nan
        
#         print(div.prettify())
        try:
            
            b_items = item.find_all("b")
            center_items = item.find_all("center")
            
            tag_serial_number = b_items[0].text
            date_last_known_plate = b_items[1].text
            tag_class = b_items[2].text
            state = center_items[0].text
            number_plate = center_items[1].text
            
        except(Exception):
              print(0)
#             print(item)
#             print(Exception.mro)
#             print(b_items.prettify())
        row.append(tag_serial_number)
        row.append(date_last_known_plate)
        row.append(tag_class)
        row.append(state)
        row.append(number_plate)
        data.append(row)
PATH_TOLL_ID = "C:\\Users\\User\\Desktop\\blob_storage\\toll_id.csv"
pd.DataFrame(data=data, columns=[
    'tag_serial_number', 
    'date_last_known_plate', 
    'tag_class',
    'state',
    'number_plate']).sort_values(by="number_plate").to_csv(PATH_TOLL_ID ,index=False)

# %%
PATH_LINKT = "C:\\Users\\User\\Desktop\\blob_storage\\linkt.html"

with open(PATH_LINKT, 'r') as f:
    contents = f.read()
    soup = bs(contents, 'html.parser')
#     print(soup.prettify())
    data = []
    for item in soup.find_all("div", class_="tagDetailsBox"):
        row = []
        last_known_plate = ""
        tag_serial_number = 0
        tag_class = ""
        state = ""
        number_plate = ""
        center_items = item.find_all("center")
        print(center_items)
# Out:
# []
# []
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CN69XN</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XO62AB</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CH32FV</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CQ64LO</center>]
# []
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN44QZ</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN81VB</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN62UD</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">EGY52A</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN76VB</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN23UV</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">EGY52A</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN52IJ</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN23KQ</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">BL82AG</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN13KR</center>]
# []
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CG94KY</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CJ65PS</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CBB804</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CN41XN</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN97FC</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CM97HV</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">YSE640</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN80YD</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN75OS</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CG06UT</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN71FD</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN10HU</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CF71JM</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CL98LU</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CL02TB</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">DA59TU</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN19IN</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN25GD</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CJ47JV</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XPL658</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">AF06YN</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN65IJ</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">BY46TO</center>]
# []
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN06OJ</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CMA32H</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">XN72MK</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CV57SC</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CV50EC</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">CF48ED</center>]
# []
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">BDH84Y</center>]
# []
# []
# []
# []
# []
# []
# []
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">DZU72Z</center>]
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">EDD02K</center>]
# []
# [<center class="tagPlateState">NSW</center>, <center class="tagPlateRego">DZP19C</center>]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
# Out:
# 74
