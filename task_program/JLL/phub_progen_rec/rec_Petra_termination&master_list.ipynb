# %%
import pandas as pd
import numpy as np

# %%
IPATH_OFFPROP = "C:\\Users\\Gordon.Tang\\OneDrive - JLL\\Property OFF\\master_Properties_deactivated.xlsx"
IPATH_PETRA = "C:\\Users\\Gordon.Tang\\OneDrive - JLL\\Property OFF\\Petra Terminations 22.02.2022(provided_by_lyn).xlsx" 

df_offprop = pd.read_excel(IPATH_OFFPROP)
df_petra = pd.read_excel(IPATH_PETRA)
df_petra['AssociatedProgenLeaseId_Name'] = df_petra['AssociatedProgenLeaseId_Name'].str.lower()

df_offprop['addr1'] = df_offprop['Property Name'].str.split(" - ", expand=True)[2]
df_offprop['street_name']= df_offprop['addr1'].str.split(" ", expand=True)[1].str.lower()
street_names = df_offprop['street_name'].values

# any_streetInPetra

def any_streetInPetra(street_arr):
    
    for streetName in street_names:
        
        if streetName in df_petra['AssociatedProgenLeaseId_Name']:
            return "y"
        
df_petra["off_status"] = df_petra.apply(, axis=1)
df_petra
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# ...

# %%
df_offprop
# Out:
#             Date Action                              Gordon Note / comment  \
# 0   2022-02-18 00:00:00                      JDE & Corrigo - Please check
# 1            21/02/2022                                JDE - Please check
# 2   2022-02-01 00:00:00  unsure status - Progen - Status - Active / Act...
# 3            21/02/2022                                JDE - Please check
# 4            21/02/2022                                JDE - Please check
# 5            21/02/2022                                JDE - Please check
# 6   2022-02-07 00:00:00  unsure status - Progen - Status - Overholding ...
# 7   2022-02-01 00:00:00                      JDE & Corrigo - Please check
# 8   2022-02-01 00:00:00                      JDE & Corrigo - Please check
# 9   2022-02-18 00:00:00                      will terminate at 31/Mar/2022
# 10  2022-02-18 00:00:00  unsure status - Progen - Status - Active / Act...
# 11  2022-02-01 00:00:00  unsure status - Progen - Status - Active / Act...
# ...

# %%
# df_petra[df_petra['AssociatedProgenLeaseId_Name'].isin(street_names)]

# %%
df_petra
# Out:
#    BUName RequesterName                 Created                 Changed  \
# 0     WDP       Sabrina 2022-02-21 06:49:41.560 2022-02-21 06:51:17.607
# 1     QML         Jayne 2022-02-17 03:54:01.400 2022-02-17 07:26:51.497
# 2     WDP       Sabrina 2022-01-25 00:55:49.283 2022-02-04 04:33:14.643
# 3     WDP       Sabrina 2022-01-24 03:07:09.013 2022-01-27 04:29:43.737
# 4     WDP       Sabrina 2022-01-19 05:56:39.147 2022-01-21 06:18:23.803
# 5     QML         Jayne 2022-01-18 23:40:53.910 2022-01-19 00:58:30.760
# 6     WDP       Sabrina 2021-12-08 09:24:24.510 2022-01-11 01:35:43.520
# 7     WDP       Sabrina 2021-12-08 09:22:51.213 2022-01-11 01:36:00.427
# 8     LAV        Hannah 2021-12-05 23:05:13.970 2021-12-16 23:13:30.363
# 9     LAV        Hannah 2021-12-05 22:28:43.210 2021-12-07 01:36:08.333
# 10    DOR           Amy 2021-12-02 23:27:26.460 2021-12-08 01:14:30.353
# 11    DOR           Amy 2021-12-02 00:10:22.310 2021-12-08 01:10:18.560
# ...
