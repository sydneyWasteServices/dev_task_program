# %%
import pandas as pd
import numpy as np
import typing
df = pd.read_csv("../df_test1.csv")
df
# Out:
#              Date                         Customer Name  \
# 0      22/12/2020                    Compounded Pty Ltd
# 1      22/12/2020             Lonergan Research Pty Ltd
# 2      22/12/2020                           MLH Pty Ltd
# 3      22/12/2020                           Sign Up Now
# 4      22/12/2020                             Suby Tech
# ...           ...                                   ...
# 30278   2/12/2020           179 Hyde Investment Pty LTd
# 30279   2/12/2020  Adina Apartment Hotel Sydney Airport
# 30280   2/12/2020               Matteo Restaurant & Bar
# 30281   2/12/2020                  Republic 2 - SP65530
# 30282   2/12/2020              WasteSpec - Kiaora Place
#
#                     Address 1          City State  PostCode  Qty Scheduled  \
# 0      Unit25/56 O'Riordan St    Alexandria   NSW    2015.0              1
# 1             263 Clarence St        Sydney   NSW    2000.0              1
# ...
