# %%
import pandas as pd
import numpy as np

# %%
PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\expenses_truck\\all_other_mv_expense\\to_be_process\\20th_2021.xlsx'          
df = pd.read_excel(PATH)

df.Date = pd.to_datetime(df.Date, format='%d/%m/%Y')

COMPLETE_PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\expenses_truck\\all_other_mv_expense\\to_be_process\\20th_2021_.xlsx'          
df[df.Date.between('20210519', '20210525')].to_excel(COMPLETE_PATH)

# %%
# Out:
#      catID                            cat       Date  \
# 0    OTHER                          OTHER 2021-05-31
# 1       CC           MV R&M - Cab&Chassic 2021-05-19
# 2       CC           MV R&M - Cab&Chassic 2021-05-20
# 3       CC           MV R&M - Cab&Chassic 2021-05-25
# 4       CC           MV R&M - Cab&Chassic 2021-05-25
# 5       CC           MV R&M - Cab&Chassic 2021-05-26
# 6       CC           MV R&M - Cab&Chassic 2021-05-26
# 7       CC           MV R&M - Cab&Chassic 2021-05-26
# 8       CC           MV R&M - Cab&Chassic 2021-05-27
# 9       CC           MV R&M - Cab&Chassic 2021-05-28
# 10      CC           MV R&M - Cab&Chassic 2021-05-29
# 11      CC           MV R&M - Cab&Chassic 2021-05-29
# 12      CC           MV R&M - Cab&Chassic 2021-05-31
# 13      CB        MV R&M - Compactor/Body 2021-05-24
# 14      CB        MV R&M - Compactor/Body 2021-05-25
# 15      CB        MV R&M - Compactor/Body 2021-05-25
# 16      CB        MV R&M - Compactor/Body 2021-05-25
# 17      CB        MV R&M - Compactor/Body 2021-05-31
# 18      CB        MV R&M - Compactor/Body 2021-05-31
# 19      CB        MV R&M - Compactor/Body 2021-06-01
# 20      CB        MV R&M - Compactor/Body 2021-06-01
# 21      CB        MV R&M - Compactor/Body 2021-06-01
# 22      CB        MV R&M - Compactor/Body 2021-06-01
# 23      MC           MV R&M - Misc Consum 2021-05-20
# 24      MC           MV R&M - Misc Consum 2021-06-01
# 25  LABOUR  MV Workshop Contractor Labour 2021-05-25
# 26  LABOUR  MV Workshop Contractor Labour 2021-05-25
# 27  LABOUR  MV Workshop Contractor Labour 2021-05-25
# 28  LABOUR  MV Workshop Contractor Labour 2021-05-25
# 29  LABOUR  MV Workshop Contractor Labour 2021-05-25
# 30  LABOUR  MV Workshop Contractor Labour 2021-05-31
# 31  LABOUR  MV Workshop Contractor Labour 2021-05-31
# 32  LABOUR  MV Workshop Contractor Labour 2021-05-31
# 33  LABOUR  MV Workshop Contractor Labour 2021-05-31
#
#                                             Memo    Debit             Job No.
# 0                              Purchase; SUPAGAS   312.00               FLEET
# 1                          Purchase; MULTISPARES    53.13              CV50EC
# 2                          Purchase; MULTISPARES   129.63              XN62UD
# 3      Purchase; Tony Perino Engineering Pty Ltd   456.00           New Truck
# 4      Purchase; Tony Perino Engineering Pty Ltd   110.00              XN71FD
# 5                 Purchase; T.M.Elite Automatics   500.00              XN75OS
# 6                 Purchase; T.M.Elite Automatics   534.20           New Truck
# 7                 Purchase; T.M.Elite Automatics   534.20      New Front Lift
# 8                          Purchase; MULTISPARES   736.88              CQ64LO
# 9                          Purchase; MULTISPARES   809.36  New Skip Bin Truck
# 10               Purchase; Gazza's Paint & Panel  4500.00           New Truck
# 11                Purchase; Buddy Motor Trimming   200.00              CQ64LO
# 12                         Purchase; MULTISPARES   165.97              CG94KY
# 13  Purchase; Penblack Pty Ltd RYCO 24/7 Penrith   312.83              XN10HU
# 14     Purchase; Tony Perino Engineering Pty Ltd   144.00           New Truck
# 15     Purchase; Tony Perino Engineering Pty Ltd    80.00              XPL658
# 16     Purchase; Tony Perino Engineering Pty Ltd  3800.00              CN41XN
# 17                    Purchase; Austlift Pty Ltd  5850.00              DA59TU
# 18           Purchase; Pirtek Smithfield Pty Ltd   131.48              XN80YD
# 19     Purchase; Tony Perino Engineering Pty Ltd   711.00              XN25GD
# 20     Purchase; Tony Perino Engineering Pty Ltd   391.00              CN41XN
# 21     Purchase; Tony Perino Engineering Pty Ltd   217.00      New Front Lift
# 22  Purchase; Penblack Pty Ltd RYCO 24/7 Penrith   250.95              XN75OS
# 23                              Purchase; Cedray    29.58               FLEET
# 24     Purchase; Tony Perino Engineering Pty Ltd   345.00               FLEET
# 25     Purchase; Tony Perino Engineering Pty Ltd  1560.00               FLEET
# 26     Purchase; Tony Perino Engineering Pty Ltd  2520.00               FLEET
# 27     Purchase; Tony Perino Engineering Pty Ltd   900.00               FLEET
# 28     Purchase; Tony Perino Engineering Pty Ltd  1000.00               FLEET
# 29     Purchase; Tony Perino Engineering Pty Ltd  1125.00               FLEET
# 30     Purchase; Tony Perino Engineering Pty Ltd  1380.00               FLEET
# 31     Purchase; Tony Perino Engineering Pty Ltd  2400.00               FLEET
# 32     Purchase; Tony Perino Engineering Pty Ltd  1440.00               FLEET
# 33     Purchase; Tony Perino Engineering Pty Ltd  1000.00               FLEET

# %%
PATH_MVEXP = 'D:\\Run Analysis\\BLOB_STORAGE\\expenses_truck\\all_other_mv_expense\\to_be_process\\17th_2021.xlsx'
PATH_ROS = 'D:\\Run Analysis\\BLOB_STORAGE\\Roster\\weekly_roster_processed\\17th_2021.xlsx'
PATH_OLDROS = 'D:\\Run Analysis\\BLOB_STORAGE\\Roster\\Rearranged_past_roster\\All_Past_Sorted_ROSTER.csv'

df_mvexp = pd.read_excel(PATH_MVEXP)
df_ros = pd.read_excel(PATH_ROS)

df_mvexp.iloc[:,3] = pd.to_datetime(df_mvexp.iloc[:,3], format="%d/%m/%Y")
df_mvexp
# Out:
#      catID                            cat   ID No.       Date  \
# 0       CC           MV R&M - Cab&Chassic  4154238 2021-04-28
# 1       CC           MV R&M - Cab&Chassic  4154240 2021-04-28
# 2       CC           MV R&M - Cab&Chassic  4154241 2021-04-28
# 3       CC           MV R&M - Cab&Chassic  4154244 2021-04-28
# 4       CC           MV R&M - Cab&Chassic  4154247 2021-04-28
# 5       CC           MV R&M - Cab&Chassic  4154250 2021-04-28
# 6       CC           MV R&M - Cab&Chassic  4154239 2021-04-29
# 7       CC           MV R&M - Cab&Chassic  4154243 2021-04-29
# 8       CC           MV R&M - Cab&Chassic  4154284 2021-04-29
# 9       CC           MV R&M - Cab&Chassic  4154285 2021-04-29
# 10      CC           MV R&M - Cab&Chassic  4154286 2021-04-29
# 11      CC           MV R&M - Cab&Chassic  4154178 2021-04-30
# 12      CC           MV R&M - Cab&Chassic  4154242 2021-04-30
# 13      CC           MV R&M - Cab&Chassic  4154222 2021-05-02
# 14      CC           MV R&M - Cab&Chassic  4154222 2021-05-02
# 15      CC           MV R&M - Cab&Chassic  4154222 2021-05-02
# 16      CB        MV R&M - Compactor/Body  4154282 2021-04-28
# 17      CB        MV R&M - Compactor/Body  4154176 2021-04-29
# 18      CB        MV R&M - Compactor/Body  4154176 2021-04-29
# 19      CB        MV R&M - Compactor/Body  4154176 2021-04-29
# 20      CB        MV R&M - Compactor/Body  4154176 2021-04-29
# 21      CB        MV R&M - Compactor/Body  4154176 2021-04-29
# 22      CB        MV R&M - Compactor/Body  4154223 2021-05-02
# 23      MC           MV R&M - Misc Consum  4154277 2021-04-28
# 24   TYRES               M.V R&M - Tyres   4154249 2021-04-29
# 25   TYRES               M.V R&M - Tyres   4154278 2021-04-29
# 26   TYRES               M.V R&M - Tyres   4154280 2021-04-29
# 27  LABOUR  MV Workshop Contractor Labour  4154216 2021-05-02
# 28  LABOUR  MV Workshop Contractor Labour  4154217 2021-05-02
# 29  LABOUR  MV Workshop Contractor Labour  4154218 2021-05-02
# 30  OTHER2              Fines & Penalties  4154179 2021-04-30
#
#                                          Memo    Debit  Credit Job No.
# 0                       Purchase; MULTISPARES   105.52     NaN  XN62UD
# 1         Purchase; CITY HINO as IVECO Sydney   148.91     NaN  XN06OJ
# 2         Purchase; CITY HINO as IVECO Sydney   131.52     NaN  CF48ED
# 3         Purchase; CITY HINO as IVECO Sydney   501.03     NaN  XN13KR
# 4                       Purchase; MULTISPARES    31.27     NaN  XN71FD
# 5         Purchase; CITY HINO as IVECO Sydney   162.67     NaN  CJ65PS
# 6         Purchase; CITY HINO as IVECO Sydney    62.74     NaN  XN06OJ
# 7         Purchase; CITY HINO as IVECO Sydney    63.77     NaN  CF48ED
# 8                       Purchase; MULTISPARES   135.00     NaN  XN80YD
# 9                       Purchase; MULTISPARES   375.68     NaN  XN62UD
# 10                      Purchase; MULTISPARES    69.18     NaN  XN62UD
# 11    Purchase; D J Burnes and L G Automotive   180.00     NaN  CMA32H
# 12        Purchase; CITY HINO as IVECO Sydney    38.00     NaN  CF48ED
# 13  Purchase; Tony Perino Engineering Pty Ltd   120.00     NaN  CQ64LO
# 14  Purchase; Tony Perino Engineering Pty Ltd   240.00     NaN  XN10HU
# 15  Purchase; Tony Perino Engineering Pty Ltd   120.00     NaN  CL02TB
# 16        Purchase; Pirtek Smithfield Pty Ltd   232.57     NaN  CJ65PS
# 17  Purchase; TSM SIGNS Total Sign Management   175.00     NaN   FLEET
# 18  Purchase; TSM SIGNS Total Sign Management   175.00     NaN  XN49YC
# 19  Purchase; TSM SIGNS Total Sign Management   175.00     NaN  CF71JM
# 20  Purchase; TSM SIGNS Total Sign Management   175.00     NaN  XN80YD
# 21  Purchase; TSM SIGNS Total Sign Management    50.00     NaN  XN62UD
# 22  Purchase; Tony Perino Engineering Pty Ltd   240.00     NaN  XN65IJ
# 23                 Purchase; OMEGA Industries   335.00     NaN   FLEET
# 24          Purchase; West City Tyres Pty Ltd   245.00     NaN  XN81VB
# 25          Purchase; West City Tyres Pty Ltd   630.00     NaN  CL02TB
# 26          Purchase; West City Tyres Pty Ltd    60.00     NaN  XN10HU
# 27  Purchase; Tony Perino Engineering Pty Ltd  1000.00     NaN   FLEET
# 28  Purchase; Tony Perino Engineering Pty Ltd  2400.00     NaN   FLEET
# 29  Purchase; Tony Perino Engineering Pty Ltd  1000.00     NaN   FLEET
# 30          Purchase; Office of State Revenue   272.00     NaN  DZU72Z

# %%
# df_mvexp.groupby('catID')['Debit'].sum()
# df_mvexp
# df.groupby(['Job No.','catID'])['Debit'].sum()

df_ros.Primary_truck = df_ros.Primary_truck.str.replace(' ','')
df_ros
# Out:
#           Date    Run_type Primary_employeeID Secondary_employeeID  \
# 0   2021-04-28  NIGHT RUNS           swaklado                  NaN
# 1   2021-04-29  NIGHT RUNS           swaklado                  NaN
# 2   2021-04-30  NIGHT RUNS           swaklado                  NaN
# 3   2021-05-03  NIGHT RUNS           swaklado                  NaN
# 4   2021-05-04  NIGHT RUNS           swaklado                  NaN
# ..         ...         ...                ...                  ...
# 132 2021-04-28    DAY RUNS             irdeaz                  NaN
# 133 2021-04-29    DAY RUNS             irdeaz                  NaN
# 134 2021-04-30    DAY RUNS             irdeaz                  NaN
# 135 2021-05-01    DAY RUNS             irdeaz                  NaN
# 136 2021-05-04    DAY RUNS             irdeaz                  NaN
#
#     Primary_driver_Name Secondary_Driver_Name Primary_route Satellite_Route_1  \
# 0            ADONIS AKL                   NaN           RLE               NaN
# 1            ADONIS AKL                   NaN           RLE               NaN
# 2            ADONIS AKL                   NaN           RLE               NaN
# 3            ADONIS AKL                   NaN           RLE               NaN
# 4            ADONIS AKL                   NaN           RLE               NaN
# ..                  ...                   ...           ...               ...
# 132            ZAC DEAN                   NaN           RL7               NaN
# 133            ZAC DEAN                   NaN           RL7               NaN
# 134            ZAC DEAN                   NaN           RL7               NaN
# 135            ZAC DEAN                   NaN           RL7               NaN
# 136            ZAC DEAN                   NaN           RL7               NaN
#
#      Satellite_Route_2 Primary_truck Alternative_Truck  \
# 0                  NaN        CL98LU               NaN
# 1                  NaN        CL98LU               NaN
# 2                  NaN        CL98LU               NaN
# 3                  NaN        CL98LU               NaN
# 4                  NaN        CL02TB               NaN
# ..                 ...           ...               ...
# 132                NaN        XN44QZ               NaN
# 133                NaN        XN44QZ               NaN
# 134                NaN        XN44QZ               NaN
# 135                NaN        XN44QZ               NaN
# 136                NaN        XN44QZ               NaN
#
#     Subcontracted_From/Special_Client
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 132                               NaN
# 133                               NaN
# 134                               NaN
# 135                               NaN
# 136                               NaN
#
# [137 rows x 12 columns]
