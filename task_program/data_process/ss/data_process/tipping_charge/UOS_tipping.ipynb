# %%
import pandas as pd
import numpy as np

# %%
PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\tipping_weekly\\waste_edge_tipping\\17th_2021.csv'
df = pd.read_csv(PATH)
df[['Route No', 'Weekday']]= df['Route No'].str.split('-', 1, expand=True)
df['Route Date'] = pd.to_datetime(df['Route Date'], format='%d-%b-%Y', errors='coerce')
df['Disposal Date'] = pd.to_datetime(df['Disposal Date'], format='%d-%b-%Y', errors='coerce')
df['Tip Site'] = df['Tip Site'].str.lower()
UOS_ROUTE = ['NEPCB','UOSCB','UOSCO','UOSGW','CMDCB','CMDGW','CUMCB','CUMGW','NEPGW']
df_uos = df[df['Route No'].isin(UOS_ROUTE)]
df_uos_minor = df_uos.loc[~(df_uos['Gross Weight'] > 0 ) & ~(df_uos['Gross Weight'] > 0 )]

# %%
df_uos_minor['Weight_in_ton'] = df_uos_minor['Weight'] / 1000
# Out:
# <ipython-input-65-c8464aa14088>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uos_minor['Weight_in_ton'] = df_uos_minor['Weight'] / 1000

# %%
# Out:
#   Route No  Weight_in_ton
# 0    CUMGW          0.065
# 1    UOSGW         15.101

# %%
df_uos_minor.groupby('Route No')['Weight'].sum()
# Out:
# Route No
# CUMGW     0.065
# UOSGW    15.101
# Name: Weight, dtype: float64

# %%
trucks = ['CQ64LO', 'XN76VB']
df[df['Truck No'].isin(trucks)]['Route No'].unique()
# Out:
# array(['CUMGW', 'UOSGW', 'UOSCB', 'UOSCO', 'RL9'], dtype=object)

# %%
df[df['Route No'].eq('RL9')]
# Out:
#       Sequence No  Booking No Customer Details Route No Truck No Route Date  \
# 198     235950941         0.0              NaN      RL9   BL82AG 2021-04-28
# 206     233010568         0.0              NaN      RL9   BL82AG 2021-04-28
# 207     233202080         0.0              NaN      RL9   BL82AG 2021-04-28
# 427     234399335         0.0              NaN      RL9   BL82AG 2021-04-29
# 434     234219013         0.0              NaN      RL9   BL82AG 2021-04-29
# 672     235535242         0.0              NaN      RL9   BL82AG 2021-04-30
# 681     235462660         0.0              NaN      RL9   BL82AG 2021-04-30
# 770     236540900         0.0              NaN      RL9   BL82AG 2021-05-01
# 777     236540704         0.0              NaN      RL9   BL82AG 2021-05-01
# 778     236540822         0.0              NaN      RL9   BL82AG 2021-05-01
# 793     237017867         0.0              NaN      RL9   BY46TO 2021-05-02
# ...

# %%
# df[df['Tip Site'].eq('polytrade')]

# df[df['Waste Type'].eq('PC')]
df['Route No'].unique()
# Out:
# array(['RRR', 'AUSSKIP', 'CUMGW', 'FL2', 'FLG', 'RL7', 'SUE', 'SWG',
#        'UOSGW', 'HOOKCB', 'RL5', 'RLP', 'DOY', 'RLC', 'RL8', 'RLR',
#        'UOSCB', 'RED', 'HYG', 'RL9', 'RLJ', 'RL2', 'BR1', 'RLE', 'BR2',
#        'RL1', 'RLK', 'RLD', 'RL4', 'BR3', 'RLI', 'RLH', 'RL6', 'UOSCO',
#        'RRNW', 'REP', 'RLG', 'HOOK1'], dtype=object)

# %%
ALL_CB = ['FLP','HYG','RED','RL5','RL6','RL8','RLP','RLR','UOSCB','CMDCB']

df[df['Route No'].isin(ALL_CB)]
# Out:
#       Sequence No  Booking No Customer Details Route No Truck No Route Date  \
# 188     233573095         0.0              NaN      RL5   CF71JM 2021-04-28
# 189     233573249         0.0              NaN      RLP   CH32FV 2021-04-28
# 192     234388949         0.0              NaN      RL8   XN62UD 2021-04-28
# 193     234399373         0.0              NaN      RLR   CG94KY 2021-04-28
# 194     234399854         0.0              NaN      RL8   XN62UD 2021-04-28
# 195     233572633         0.0              NaN    UOSCB   CQ64LO 2021-04-28
# 196     234399374         0.0              NaN      RED   CG06UT 2021-04-28
# 197     233573658         0.0              NaN      HYG   CF48ED 2021-04-28
# 418     235137510         0.0              NaN      RL6   XN62UD 2021-04-29
# 419     234934942         0.0              NaN      RL5   CF71JM 2021-04-29
# 420     234934704         0.0              NaN      RLP   CH32FV 2021-04-29
# ...
