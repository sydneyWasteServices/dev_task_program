# %%
import pandas as pd
import numpy as np

# %%
# PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\Roster\\weekly_roster_processed\\18th_2021_.xlsx'
# df = pd.read_excel(PATH)
# PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\tipping_weekly\\waste_edge_tipping\\18th_2021.csv'
PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\Visy_Contract_Report\\Apr_2021.xlsx'
PATH_ROS = 'D:\\Run Analysis\\BLOB_STORAGE\\Roster\\weekly_roster_processed\\14th_2021.xlsx'

df_ros = pd.read_excel(PATH_ROS)
df = pd.read_excel(PATH)
# df = pd.read_csv(PATH)
# df['Route No'] = df['Route No'].str.split('-', 1, expand=True)[0]
# & df.Act_Qty > 0
df_niwpr = df[(df.Route.eq('NIWPR2') | df.Route.eq('NIWPR1'))]
df_niwpr = df_niwpr[df_niwpr.Act_Qty.gt(0)]
df_niwpr.Date = pd.to_datetime(df_niwpr.Date, format='%Y%m%d')

df_14th_2021 = df_niwpr[df_niwpr.Date.between('20210407', '20210413')]

df_14th_2021['Total_Price'] = df_14th_2021.Price * df_14th_2021.Act_Qty

# df_14th_2021
# Out:
# <ipython-input-2-a7cd09a72c6b>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_14th_2021['Total_Price'] = df_14th_2021.Price * df_14th_2021.Act_Qty

# %%
# df_14th_2021
# Out:
#       Route  RS Number  Customer                                 Name  \
# 446  NIWPR1     964987     79788  NSW GC6034 PUBLIC SERVICE ASSOCIATE
# 447  NIWPR1     964987    140511               PAGE UP PEOPLE PTY LTD
# 448  NIWPR1     964987    173981                        HOTEL STELLAR
# 449  NIWPR1     964987    123126  DARLINGTON AFTERCARE ASSOCIATION IN
# 450  NIWPR1     964987    265061                               THRIVE
# ..      ...        ...       ...                                  ...
# 882  NIWPR2     965466     80304                   AUSTRALIAN HEARING
# 883  NIWPR2     965466     98224  DEPT. OF FAMILY & COMMUNITY SERVICE
# 884  NIWPR2     965466     62759       CENTRELINK LIVERPOOL NSWGC6034
# 885  NIWPR2     965466     65851                       CLUB LIVERPOOL
# 886  NIWPR2     965466     36743               SNACK BRANDS AUSTRALIA
#
#     Material    Vessel       Date  Act_Qty  Price  Total_Price
# 446      WPR  WBWPR240 2021-04-07        6  10.77        64.62
# ...

# %%
df_ros_niwpr = df_ros[df_ros.Primary_route.eq('NIWPR1') | df_ros.Primary_route.eq('NIWPR2')]
df_ros_niwpr.Primary_truck = df_ros_niwpr.Primary_truck.str.replace(' ', '')

df_ros_niwpr
# Out:
# C:\Users\gordon\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#          Date  Run_type Primary_employeeID Secondary_employeeID  \
# 74 2021-04-13  DAY RUNS           swjusjoh                  NaN
# 75 2021-04-12  DAY RUNS           swjusjoh                  NaN
# 77 2021-04-09  DAY RUNS           swjusjoh                  NaN
# 78 2021-04-08  DAY RUNS           swjusjoh                  NaN
# 79 2021-04-07  DAY RUNS           swjusjoh                  NaN
# 87 2021-04-13  DAY RUNS             swliqi                  NaN
# 88 2021-04-12  DAY RUNS             swliqi                  NaN
# 89 2021-04-09  DAY RUNS             swliqi                  NaN
# ...

# %%
df_ros_niwpr.Primary_truck.unique()
# Out:
# array(['CG94KY', 'BY46TO', 'XPL658'], dtype=object)

# %%
df_ros_niwpr
# Out:
#          Date  Run_type Primary_employeeID Secondary_employeeID  \
# 74 2021-04-13  DAY RUNS           swjusjoh                  NaN
# 75 2021-04-12  DAY RUNS           swjusjoh                  NaN
# 77 2021-04-09  DAY RUNS           swjusjoh                  NaN
# 78 2021-04-08  DAY RUNS           swjusjoh                  NaN
# 79 2021-04-07  DAY RUNS           swjusjoh                  NaN
# 87 2021-04-13  DAY RUNS             swliqi                  NaN
# 88 2021-04-12  DAY RUNS             swliqi                  NaN
# 89 2021-04-09  DAY RUNS             swliqi                  NaN
# 90 2021-04-08  DAY RUNS             swliqi                  NaN
# 91 2021-04-07  DAY RUNS             swliqi                  NaN
#
#    Primary_driver_Name Secondary_Driver_Name Primary_route Satellite_Route_1  \
# 74        JOHN JUSTICE                   NaN        NIWPR2               CBK
# 75        JOHN JUSTICE                   NaN        NIWPR2               NaN
# ...

# %%
fuelID = 'D:\\Run Analysis\\BLOB_STORAGE\\EmpID_FuelID.csv'
df_fuelID = pd.read_csv(fuelID, dtype={'card_ID': np.int64})
df_fuelID
# df_fuelID[df_fuelID.lastname.str.contains('justice')]
# df_fuelID[df_fuelID.lastname.str.contains('li')]

# Li => 7071 3400 7963 0116

# justice => 70713400 9337 1952 .00
# Out:
#         Account           card_ID EmployeeID                    Name lastname  \
# 0   600851334.0  7071340092560449   swaklado             Akl, Adonis      akl
# 1   600851334.0  7071340085452331    subcon1            Alan, Walden     alan
# 2   600851334.0  7071340092810703   swedwben  Edwards, Benjamin John  edwards
# 3   200600325.0  7071340079629886       ir12            Boland, Luke   boland
# 4   200600325.0  7071340080640088   swbranat     Bracey, Nathan John   bracey
# ..          ...               ...        ...                     ...      ...
# 58  200600325.0  7071340079115399        NaN                     NaN    spare
# 59  200600325.0  7071340083419027   swwarrob      Ward, Robert James     ward
# 60  200600325.0  7071340079630074   swwhinei        White, Neil John    white
# 61  200600325.0  7071340079629944     iryouc            Young, Craig    young
# 62  200600325.0  7071340084770286        NaN                     NaN    zizer
#
#       firstname
# ...

# %%
PATH_FUEL_TRANS  = 'D:\\Run Analysis\\BLOB_STORAGE\\expenses_truck\\fuel\\Caltex_fuel_transactions\\18th_2021.html'
df_fuel = pd.read_html(PATH_FUEL_TRANS, converters={'Card Number' : np.int64 })
df_fuel[0].loc[df_fuel[0]['Card Number'].eq(7071340093371952)]

7071340079630110
# df_fuel['Card Number'].dtype
# Out:
#        Account       Card Number Registration         Driver Name Trans. Type  \
# 3    600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 8    600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 21   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 26   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 34   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 48   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 55   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 60   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 68   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 77   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 84   600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# ...

# %%
df_fuel[0].loc[df_fuel[0]['Card Number'].eq(7071340079630116)]
# Out:
# Empty DataFrame
# Columns: [Account, Card Number, Registration, Driver Name, Trans. Type, Location, Trans. Ref, Trans. Date, Post Date, Amount, Amount Ex GST, Location Name]
# Index: []

# %%
df[df['Route No'].eq('RLC')]
df[df['Route No'].eq('BR1') & df['Gross Weight'].gt(0)].Weight.sum()
