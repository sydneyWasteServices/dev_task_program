# %%
import pandas as pd 
import numpy as np

# %%
ROS_PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\Roster\\weekly_roster_processed\\31th_2021.xlsx'
PAY_PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\Drivers_pay\\31th_2021.xlsx'

df_ros  = pd.read_excel(ROS_PATH)
df_pay = pd.read_excel(PAY_PATH)

df_RLI = df_ros[df_ros.Primary_route.eq('RLI')]

RLI_drivers = df_RLI.Primary_employeeID.unique()

# %%
RLI_related_df = df_ros[df_ros.Primary_employeeID.isin(RLI_drivers) | df_ros.Secondary_employeeID.isin(RLI_drivers)]
RLI_related_df.sort_values(by='Primary_employeeID')
# Out:
#           Date  Run_type Primary_employeeID Secondary_employeeID  \
# 32  2021-08-04  DAY RUNS               ir02                  NaN
# 33  2021-08-06  DAY RUNS               ir02                  NaN
# 63  2021-08-09  DAY RUNS               ir02                  NaN
# 84  2021-08-10  DAY RUNS               ir02                  NaN
# 105 2021-08-05  DAY RUNS               ir02             swansgia
# 104 2021-08-10  DAY RUNS           swansgia                  NaN
# 6   2021-08-08  DAY RUNS           swlocbra                  NaN
# 19  2021-08-10  DAY RUNS           swlocbra                  NaN
# 100 2021-08-04  DAY RUNS           swlocbra             swansgia
# 101 2021-08-06  DAY RUNS           swlocbra             swansgia
# 102 2021-08-09  DAY RUNS           swlocbra             swansgia
# 103 2021-08-07  DAY RUNS           swlocbra             swansgia
#
#     Primary_driver_Name Secondary_Driver_Name Primary_route Satellite_Route_1  \
# ...

# %%
RLI_related_df
# df_1 = df.groupby(['Primary_employeeID','Primary_route']).agg({'Run_type' : 'count'}).reset_index().rename(columns={'Run_type' : 'occurrence'})     
# df_1['total'] = df_1.groupby('Primary_employeeID')['occurrence'].cumsum()
# df_1['portion'] = df_1.occurrence / df_1.groupby('Primary_employeeID')['total'].transform(np.max)
# Out:
#           Date  Run_type Primary_employeeID Secondary_employeeID  \
# 6   2021-08-08  DAY RUNS           swlocbra                  NaN
# 19  2021-08-10  DAY RUNS           swlocbra                  NaN
# 32  2021-08-04  DAY RUNS               ir02                  NaN
# 33  2021-08-06  DAY RUNS               ir02                  NaN
# 63  2021-08-09  DAY RUNS               ir02                  NaN
# 84  2021-08-10  DAY RUNS               ir02                  NaN
# 100 2021-08-04  DAY RUNS           swlocbra             swansgia
# 101 2021-08-06  DAY RUNS           swlocbra             swansgia
# 102 2021-08-09  DAY RUNS           swlocbra             swansgia
# 103 2021-08-07  DAY RUNS           swlocbra             swansgia
# 104 2021-08-10  DAY RUNS           swansgia                  NaN
# 105 2021-08-05  DAY RUNS               ir02             swansgia
#
#     Primary_driver_Name Secondary_Driver_Name Primary_route Satellite_Route_1  \
# ...
