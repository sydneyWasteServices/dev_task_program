# %%
import pandas as pd
import numpy as np

# %%
PATH = 'D:\\Run Analysis\\BLOB_STORAGE\\expenses_truck\\all_other_mv_expense\\processed\\15th_2021.xlsx'   
df_mvExp = pd.read_excel(PATH)
PATH_1 = 'D:\Run Analysis\\BLOB_STORAGE\\Roster\\weekly_roster_processed\\15th_2021.xlsx'
df_ros = pd.read_excel(PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c429892a4341> in <module>
#       2 df_mvExp = pd.read_excel(PATH)
#       3 PATH_1 = 'D:\Run Analysis\\BLOB_STORAGE\\Roster\\weekly_roster_processed\\15th_2021.xlsx'
# ----> 4 df_ros
#
# NameError: name 'df_ros' is not defined

# %%
df_mvExp
# Out:
#     Unnamed: 0   catID Job No.    Debit Primary_truck Primary_route     ratio  \
# 0            0      CB  VMU428   199.00           NaN           NaN       NaN
# 1            1      CB  XN13KR    24.24        XN13KR           RLI  1.000000
# 2            2      CC  CL02TB   646.72        CL02TB           RL2  0.047619
# 3            3      CC  CL02TB   646.72        CL02TB           RLD  0.880952
# 4            4      CC  CL02TB   646.72        CL02TB           RLE  0.047619
# 5            5      CC  CL02TB   646.72        CL02TB           RLJ  0.023810
# 6            6      CC  CV57SC  1909.09           NaN           NaN       NaN
# 7            7      CC   FLEET   150.00           NaN           NaN       NaN
# 8            8      CC  XN62UD  1437.92        XN62UD           RL6  0.483871
# 9            9      CC  XN62UD  1437.92        XN62UD           RL8  0.516129
# 10          10      CC  XN71FD   122.28        XN71FD           RLK  1.000000
# 11          11      CC  XN76VB   255.67        XN76VB          CAMP  0.102564
# 12          12      CC  XN76VB   255.67        XN76VB           CMD  0.025641
# 13          13      CC  XN76VB   255.67        XN76VB           UNI  0.128205
# 14          14      CC  XN76VB   255.67        XN76VB           UOS  0.692308
# 15          15      CC  XN76VB   255.67        XN76VB         UOSGW  0.051282
# 16          16      CC  XN97FC    64.26        XN97FC           HYG  0.030303
# 17          17      CC  XN97FC    64.26        XN97FC           RED  0.333333
# 18          18      CC  XN97FC    64.26        XN97FC           RL2  0.030303
# 19          19      CC  XN97FC    64.26        XN97FC           RL6  0.030303
# 20          20      CC  XN97FC    64.26        XN97FC           RLC  0.515152
# 21          21      CC  XN97FC    64.26        XN97FC           RLP  0.060606
# 22          22  LABOUR  CL98LU   240.00        CL98LU           RL1  0.192308
# 23          23  LABOUR  CL98LU   240.00        CL98LU           RLD  0.096154
# 24          24  LABOUR  CL98LU   240.00        CL98LU           RLE  0.653846
# 25          25  LABOUR  CL98LU   240.00        CL98LU           RLJ  0.038462
# 26          26  LABOUR  CL98LU   240.00        CL98LU           RLP  0.019231
# 27          27  LABOUR   FLEET  6545.00           NaN           NaN       NaN
# 28          28  LABOUR  XN13KR   120.00        XN13KR           RLI  1.000000
# 29          29    REGO  DA59TU  1032.00           NaN           NaN       NaN
# 30          30   TYRES  BL82AG   240.00        BL82AG        CAMDEN  0.016949
# 31          31   TYRES  BL82AG   240.00        BL82AG           CMD  0.016949
# 32          32   TYRES  BL82AG   240.00        BL82AG           DOY  0.016949
# 33          33   TYRES  BL82AG   240.00        BL82AG           RL2  0.016949
# 34          34   TYRES  BL82AG   240.00        BL82AG           RL6  0.016949
# 35          35   TYRES  BL82AG   240.00        BL82AG           RL9  0.644068
# 36          36   TYRES  BL82AG   240.00        BL82AG           RLG  0.016949
# 37          37   TYRES  BL82AG   240.00        BL82AG           UOS  0.101695
# 38          38   TYRES  BL82AG   240.00        BL82AG          UOS   0.033898
# 39          39   TYRES  BL82AG   240.00        BL82AG    UOS CAMDEN  0.050847
# 40          40   TYRES  BL82AG   240.00        BL82AG         UOSCB  0.067797
# 41          41   TYRES  XN52IJ   180.00        XN52IJ           FL2  0.750000
# 42          42   TYRES  XN52IJ   180.00        XN52IJ           FLG  0.159091
# 43          43   TYRES  XN52IJ   180.00        XN52IJ     FLG/EXTRA  0.090909
#
#     amount_portion
# 0              NaN
# 1        24.240000
# 2        30.796190
# 3       569.729524
# 4        30.796190
# 5        15.398095
# 6              NaN
# 7              NaN
# 8       695.767742
# 9       742.152258
# 10      122.280000
# 11       26.222564
# 12        6.555641
# 13       32.778205
# 14      177.002308
# 15       13.111282
# 16        1.947273
# 17       21.420000
# 18        1.947273
# 19        1.947273
# 20       33.103636
# 21        3.894545
# 22       46.153846
# 23       23.076923
# 24      156.923077
# 25        9.230769
# 26        4.615385
# 27             NaN
# 28      120.000000
# 29             NaN
# 30        4.067797
# 31        4.067797
# 32        4.067797
# 33        4.067797
# 34        4.067797
# 35      154.576271
# 36        4.067797
# 37       24.406780
# 38        8.135593
# 39       12.203390
# 40       16.271186
# 41      135.000000
# 42       28.636364
# 43       16.363636

# %%
df_ros
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9cbfa6886aad> in <module>
# ----> 1 df_ros
#
# NameError: name 'df_ros' is not defined
